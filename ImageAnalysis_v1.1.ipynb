# %% [markdown]
# # This is my first attempt to analyse images in Python.

# %%
import numpy as np #shorthand numpy as np
#numpy is useful for mathmatical operations in Python

# %%
import matplotlib.pyplot as plt

# %%
im1 = plt.imread('Y:/DavidB/Data/Exp0094_KDM5A_IF/Well11_egfp-flKDM5A_JmjCmut_anti-H3K4me3_3_Box1_z9.tif')

# %%
# %matplotlib inline 
#This will plot the result internally (in the notebook), rather than externally

# %%
plt.imshow(im1)

# %%
import pandas as pd #shorthand the pandas module as 'pd' to save time.
#Pandas allows your to work with data frames, 
#https://towardsdatascience.com/a-quick-introduction-to-the-pandas-python-library-f1b678f34673

# %%
im2 = plt.imread('Y:/DavidB/Data/Exp0080_KDM5A/KDM5A-2_3_box2_GFP.tif')

# %%
# %matplotlib inline #You only need to do this once!
plt.imshow(im2)

# %%
# show the image without axes and in gray scale
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
#Can we count the puncta in this nucleus?

# %%
#Can we find the nucleus?
import matplotlib.pyplot as plt

# %%
im3 = plt.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_2_Box1.tif')
# %matplotlib inline
plt.imshow(im3,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#Image is the correct orientation.
#Can I skip though the array?
print("im3 ndim: ", im3.ndim) #Seems to think my image is 2D
print("im3 shape:", im3.shape)
print("im3 size: ", im3.size)
# Out:
# ('im3 ndim: ', 2)
# ('im3 shape:', (512L, 512L))
# ('im3 size: ', 262144)

# %%
#Thresholding based on 
https://github.com/luispedro/python-image-tutorial/blob/master/Segmenting%20cell%20images%20(fluorescent%20microscopy).ipynb

# %%
T_otsu = mh.otsu(dna)
print(T_otsu)
plt.imshow(dna > T_otsu)

# %%
#Do I have conda
# !conda --version
# Out:
# conda 4.5.9

# %%
# !conda update
# Out:
# CommandNotFoundError: No command 'conda -'.

# %%
##Guessing a bit here, I added the '!'
# !conda config --add channels conda-forge

# %%
# !conda install mahotas

# %%
import mahotas as mh

# %%
import matplotlib.pyplot as plt

# %%
#Use mh to import the image instead
im = mh.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_2_Box1.tif')

# %%
# %matplotlib inline
plt.imshow(im)

# %%
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#Can I skip though the array?
print("im ndim: ", im.ndim) #Seems to think my image is 2D
print("im shape:", im.shape)
print("im size: ", im.size)
# Out:
# ('im ndim: ', 2)
# ('im shape:', (512L, 512L))
# ('im size: ', 262144)

# %%
#Still thinks it is 2D
im.shape
# Out:
# (512L, 512L)

# %%
# !pip install scikit-image

# %%
from skimage import io

# %%
#This will import the 3-channel 24z stack tiff
im = io.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_2_Box1.tif')
print im.shape
# Out:
# (24L, 512L, 512L, 3L)

# %%
plt.imshow(im[1],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#Channel=0 is DAPI
plt.imshow(im[0,:,:,0],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#Channel=1 is GFP
plt.imshow(im[0,:,:,1],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#Channel=2 is Brightfield
plt.imshow(im[0,:,:,2],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)
