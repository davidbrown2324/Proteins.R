# %% [markdown]
# First, I downloaded a test TIFF image from this page called a_image.tif. Then I opened with PIL like this:
#
# >>> from PIL import Image
# >>> im = Image.open('a_image.tif')
# >>> im.show()
# This showed the rainbow image. To convert to a numpy array, it's as simple as:
#
# >>> import numpy
# >>> imarray = numpy.array(im)
# We can see that the size of the image and the shape of the array match up:
#
# >>> imarray.shape
# (44, 330)
# >>> im.size
# (330, 44)
# And the array contains uint8 values:
#
# >>> imarray
# array([[  0,   1,   2, ..., 244, 245, 246],
#        [  0,   1,   2, ..., 244, 245, 246],
#        [  0,   1,   2, ..., 244, 245, 246],
#        ...,
#        [  0,   1,   2, ..., 244, 245, 246],
#        [  0,   1,   2, ..., 244, 245, 246],
#        [  0,   1,   2, ..., 244, 245, 246]], dtype=uint8)
# Once you're done modifying the array, you can turn it back into a PIL image like this:
#
# >>> Image.fromarray(imarray)
# <Image.Image image mode=L size=330x44 at 0x2786518>

# %%
from PIL import Image

# %%
import numpy as np #shorthand numpy as np
#numpy is useful for mathmatical operations in Python

# %%
im = Image.open('Y:/DavidB/Data/Exp0094_KDM5A_IF/Well11_egfp-flKDM5A_JmjCmut_anti-H3K4me3_3_Box1_z9.tif')
im.show() #Tries to preview tiff but it sucks

# %%
import matplotlib.pyplot as plt
im = plt.imread('Y:/DavidB/Data/Exp0094_KDM5A_IF/Well11_egfp-flKDM5A_JmjCmut_anti-H3K4me3_3_Box1_z9.tif')
im.show()

# %%
im.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-47007bcef229> in <module>()
# ----> 1 im.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
# show the image
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 510.5, -0.5)

# %%
plt.imshow(im)

# %%
import os

import cellprofiler.image
import cellprofiler.measurement
import cellprofiler.object
import cellprofiler.pipeline
import cellprofiler.preferences
import cellprofiler.workspace
import numpy as np
import pandas as pd
import skimage.io
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-092222b2ac7f> in <module>()
#       1 import os
#       2
# ----> 3 import cellprofiler.image
#       4 import cellprofiler.measurement
#       5 import cellprofiler.object
#
# ImportError: No module named cellprofiler.image

# %%
# !pip install cellprofiler
# Out:
# ...
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "c:\users\davidb~1\appdata\local\temp\pip-build-pkhhhi\javabridge\setup.py", line 396, in <module>
#         ext_modules=ext_modules(),
#       File "c:\users\davidb~1\appdata\local\temp\pip-build-pkhhhi\javabridge\setup.py", line 90, in ext_modules
#         jdk_home = find_jdk()
#       File "c:\users\davidb~1\appdata\local\temp\pip-build-pkhhhi\javabridge\javabridge\locate.py", line 174, in find_jdk
#         "Failed to find the Java Development Kit. Please download and install the Oracle JDK 1.6 or later")
#     RuntimeError: Failed to find the Java Development Kit. Please download and install the Oracle JDK 1.6 or later
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in c:\users\davidb~1\appdata\local\temp\pip-build-pkhhhi\javabridge\
# ...

# %%
python -m pip install --upgrade pip
# Out:
#   File "<ipython-input-16-93493bbcf27f>", line 1
#     python -m pip install --upgrade pip
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd #shorthand the pandas module as 'pd' to save time.
#Pandas allows your to work with data frames, 
#https://towardsdatascience.com/a-quick-introduction-to-the-pandas-python-library-f1b678f34673

# %% [markdown]
# ##Try cellprofiler
# https://github.com/davidbrown2324/notebooks/blob/master/cellprofiler_demo.ipynb

# %%
import cellprofiler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-13cc1d4d3e36> in <module>()
# ----> 1 import cellprofiler
#
# ImportError: No module named cellprofiler

# %%
import cellprofiler.image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-c2161758a175> in <module>()
# ----> 1 import cellprofiler.image
#
# ImportError: No module named cellprofiler.image

# %%
import sys
sys.version
#sys.version_info
# Out:
# '2.7.12 |Anaconda 4.2.0 (64-bit)| (default, Jun 29 2016, 11:07:13) [MSC v.1500 64 bit (AMD64)]'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-50e2c9d9c6fd> in <module>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %% [markdown]
# If you’re using an enhanced shell like IPython or the Jupyter notebook, you can run system commands like those in this tutorial by prefacing them with a ! character:
# In [1]: import sys
#         !{sys.executable} --version
# Python 3.6.3
# It’s recommended to write {sys.executable} rather than plain python in order to ensure that commands are run in the Python installation matching the currently running notebook (which may not be the same Python installation that the python command refers to).

# %%
import sys
# !{sys.executable} --version
# Out:
# 'C:\Users\David' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python --version
# Out:
# Python 2.7.12 :: Anaconda 4.2.0 (64-bit)

# %%
# !pip --version
# Out:
# pip 8.1.2 from C:\Users\David Brown\Anaconda2\lib\site-packages (python 2.7)

# %% [markdown]
# # This is a helpful page to explain 'pip'
# https://packaging.python.org/tutorials/installing-packages/

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Found existing installation: pip 8.1.2
#     Uninstalling pip-8.1.2:
#       Successfully uninstalled pip-8.1.2
# Exception:
# Traceback (most recent call last):
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\basecommand.py", line 215, in main
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\commands\install.py", line 317, in run
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\req\req_set.py", line 753, in install
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\req\req_install.py", line 755, in commit_uninstall
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\req\req_uninstall.py", line 142, in commit
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\_vendor\retrying.py", line 49, in wrapped_f
#     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#   File "C:\Users\David Brown\Anaconda2\lib\site-packages\pip\_vendor\retrying.py", line 212, in call
#     raise attempt.get()
# ...

# %%
# !pip --version
# Out:
# pip 18.0 from c:\users\david brown\anaconda2\lib\site-packages\pip (python 2.7)

# %%
#Try installing cellprofiler again
# !pip install cellprofiler
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/31/74/c476bcf870942e9708bd8a94b85ddde79faf976ae52e7f55f9e4b4bdf43e/CellProfiler-3.0.0rc3-py2-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/68/87/0b016838c2a33b46b8775a3890150c93507931127cf62e9ccf27ac20db34/javabridge-1.0.17.tar.gz
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "c:\users\davidb~1\appdata\local\temp\pip-install-uxwmfk\javabridge\setup.py", line 396, in <module>
#         ext_modules=ext_modules(),
#       File "c:\users\davidb~1\appdata\local\temp\pip-install-uxwmfk\javabridge\setup.py", line 90, in ext_modules
#         jdk_home = find_jdk()
#       File "c:\users\davidb~1\appdata\local\temp\pip-install-uxwmfk\javabridge\javabridge\locate.py", line 174, in find_jdk
#         "Failed to find the Java Development Kit. Please download and install the Oracle JDK 1.6 or later")
# ...

# %%
# !python setup.py egg_info
# Out:
# python: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
os.system('java -version 2>&1 | awk -F[\\\"_] \'NR==1{print $2}\'')
# Out:
# 255

# %%
import jpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-f6afea10fd6b> in <module>()
# ----> 1 import jpy
#
# ImportError: No module named jpy

# %%
# %%javascript
# Out:
# UsageError: %%javascript is a cell magic, but the cell body is empty.

# %%
im = plt.imread('Y:/DavidB/Data/Exp0080_KDM5A/KDM5A-2_3_box2_GFP.tif')
im.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0c308c5befeb> in <module>()
#       1 im = plt.imread('Y:/DavidB/Data/Exp0080_KDM5A/KDM5A-2_3_box2_GFP.tif')
# ----> 2 im.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
# show the image
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
from PIL import Image

#...

img = Image.open('Y:/DavidB/Data/Exp0080_KDM5A/KDM5A-2_3_box2_GFP.tif')
img.show()

# %%
# %matplotlib inline
import mahotas as mh
import numpy as np
from matplotlib import pyplot as plt
from IPython.html.widgets import interact, fixed
plt.rcParams['figure.figsize'] = (10.0, 8.0) # 10 x 8 inches
plt.gray()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-3cf41b3e470b> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 import mahotas as mh
#       3 import numpy as np
#       4 from matplotlib import pyplot as plt
#       5 from IPython.html.widgets import interact, fixed
#
# ImportError: No module named mahotas

# %%
# !pip install mahotas
# Out:
# ...
#   Running setup.py bdist_wheel for mahotas: started
#   Running setup.py bdist_wheel for mahotas: finished with status 'error'
#   Complete output from command "c:\users\david brown\anaconda2\python.exe" -u -c "import setuptools, tokenize;__file__='c:\\users\\davidb~1\\appdata\\local\\temp\\pip-install-v9_wdw\\mahotas\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d c:\users\davidb~1\appdata\local\temp\pip-wheel-kmmxbm --python-tag cp27:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-2.7
#   creating build\lib.win-amd64-2.7\mahotas
#   copying mahotas\bbox.py -> build\lib.win-amd64-2.7\mahotas
#   copying mahotas\bwperim.py -> build\lib.win-amd64-2.7\mahotas
#   copying mahotas\center_of_mass.py -> build\lib.win-amd64-2.7\mahotas
#   copying mahotas\colors.py -> build\lib.win-amd64-2.7\mahotas
# ...

# %%
import mahotas as mh
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-2ca8953dc5d4> in <module>()
# ----> 1 import mahotas as mh
#
# ImportError: No module named mahotas

# %%
# !pip install --upgrade setuptools
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ff/f4/385715ccc461885f3cedf57a41ae3c12b5fec3f35cce4c8706b1a112a133/setuptools-40.0.0-py2.py3-none-any.whl
# ...
#   Found existing installation: setuptools 27.2.0
# Cannot remove entries from nonexistent file c:\users\david brown\anaconda2\lib\site-packages\easy-install.pth

# %%
# !pip install ez_setup
# Out:
# ...
#   Running setup.py bdist_wheel for ez-setup: started
#   Running setup.py bdist_wheel for ez-setup: finished with status 'done'
#   Stored in directory: C:\Users\David Brown\AppData\Local\pip\Cache\wheels\dc\e8\6b\3d5ff5a3efd7b5338d1e173ac981771e2628ceb2f7866d49ad
# Successfully built ez-setup
# ...

# %%
# !pip install mahotas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/66/12/951fe5f9787379f713dcda1598d3cca0b29a909ee8ab656514c9a2817863/mahotas-1.4.4.tar.gz
# ...
#   Running setup.py bdist_wheel for mahotas: started
#   Running setup.py bdist_wheel for mahotas: finished with status 'error'
#   Complete output from command "c:\users\david brown\anaconda2\python.exe" -u -c "import setuptools, tokenize;__file__='c:\\users\\davidb~1\\appdata\\local\\temp\\pip-install-9fjpwo\\mahotas\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d c:\users\davidb~1\appdata\local\temp\pip-wheel-oy_vsh --python-tag cp27:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-2.7
#   creating build\lib.win-amd64-2.7\mahotas
#   copying mahotas\bbox.py -> build\lib.win-amd64-2.7\mahotas
#   copying mahotas\bwperim.py -> build\lib.win-amd64-2.7\mahotas
# ...

# %%
easy_install -U setuptools
# Out:
#   File "<ipython-input-50-815332f50e1d>", line 1
#     easy_install -U setuptools
#                              ^
# SyntaxError: invalid syntax

# %%
easy_install mahotas
# Out:
#   File "<ipython-input-52-d252adf6d376>", line 1
#     easy_install mahotas
#                        ^
# SyntaxError: invalid syntax

# %%
plt.imshow(im)
