# %% [markdown]
# **Segmentation based on morphogenie**
#
# http://morphogenie.fr/segmenting-nuclei.html
#
# At this point I would like to try running this code with a stack containing multiple nuclei.
# MMstack.ome.tif files load in a different order c,z,x,y.
# They could be opened and saved first using bio-formats importer.
#
# v5.2 - I am now trying to detect nuclei by fitting polygons (openCV), to simply analysis of uneven staining

# %%
# !pip install opencv-python -vvv
# Out:
# Config variable 'Py_DEBUG' is unset, Python ABI tag may be incorrect
# Config variable 'WITH_PYMALLOC' is unset, Python ABI tag may be incorrect
# Config variable 'Py_UNICODE_SIZE' is unset, Python ABI tag may be incorrect
# Created temporary directory: c:\users\davidb~1\appdata\local\temp\pip-ephem-wheel-cache-m4a8fk
# Created temporary directory: c:\users\davidb~1\appdata\local\temp\pip-req-tracker-u4ktca
# Created requirements tracker 'c:\\users\\davidb~1\\appdata\\local\\temp\\pip-req-tracker-u4ktca'
# Created temporary directory: c:\users\davidb~1\appdata\local\temp\pip-install-aevpse
# Collecting opencv-python
#   1 location(s) to search for versions of opencv-python:
#   * https://pypi.org/simple/opencv-python/
#   Getting page https://pypi.org/simple/opencv-python/
#   Looking up "https://pypi.org/simple/opencv-python/" in the cache
#   No cache entry available
#   Starting new HTTPS connection (1): pypi.org:443
#   https://pypi.org:443 "GET /simple/opencv-python/ HTTP/1.1" 200 32544
#   Updating cache with response from "https://pypi.org/simple/opencv-python/"
#   Caching due to etag
#   Analyzing links from page https://pypi.org/simple/opencv-python/
#     Skipping link https://files.pythonhosted.org/packages/e3/09/6d175ca54a4fd3072b4575e971140ced19a96fffe75828358c72b29c6147/opencv_python-3.1.0.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=d316c9660ed5f2625a69425c52d391dedd4df3fef11f2ed50dcce97f3e567827 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/42/64/fabb6af7858c346cf946deccbadee9b7fb2bb38d18d1b7de12b87675ce50/opencv_python-3.1.0.0-cp27-cp27m-manylinux1_i686.whl#sha256=4ba17d5ce5c7f3ad39c50ce46c3c6af0bf2d77df6382840310352e0d9dd9be8a (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/01/37/e300596d6b1e64cdc1d40dd73eef0c590e249413548b0fd0ccdd4eaa4f63/opencv_python-3.1.0.0-cp27-cp27m-manylinux1_x86_64.whl#sha256=01b93ae23e4f69b66438ae165e94fb51847c4bebdce4c07eead514360d719b35 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/04/7e/0f24131a6dc4d6af6305e58742305fbdaa2abcea34e4d82324fe29edb093/opencv_python-3.1.0.0-cp27-cp27m-win32.whl#sha256=c410a37a5a19d81c20852e683a24f325a886323e8578644a970ba33eff77525d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/ac/3a/beeefa714a5d11625876f46ef59c973861db742daa462d38872233b7b542/opencv_python-3.1.0.0-cp27-cp27m-win_amd64.whl#sha256=527cd78e19d966e60b968fcfc9c61e134acb6ac40ced32443237bb4dade0a226 (from https://pypi.org/simple/opencv-python/), version: 3.1.0.0
#     Skipping link https://files.pythonhosted.org/packages/1c/34/bd79841405ddcc7e89d059fa7c1cfb016f63d38b8100db49085f779ea85d/opencv_python-3.1.0.0-cp27-cp27mu-manylinux1_i686.whl#sha256=cd9ee2b69388d9f9f815919ffdf1dced14256aab6695afd6076337d1d002a6bb (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/9b/08/6faed2c71086dbbeb25e89cff0b4f19cfa6bcd0699ca1ba3aed4bb8255a2/opencv_python-3.1.0.0-cp27-cp27mu-manylinux1_x86_64.whl#sha256=b629e2a2c0ab0f2aeaf308144e68eb023cb611e3e7f6565558d853cd68ff4da0 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f9/bf/8eb3cb660c00fefcfddab4d6e04d3cda3a2de15c63a8f8953f23f4f1489a/opencv_python-3.1.0.0-cp33-cp33m-manylinux1_i686.whl#sha256=78d982385b5030da409d4fe6cb215b9edfbeff93e9d88315dbfae225a30ba82b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/69/c6/3efdb644feff20751c0fcd66274c50db2ae1ee8525802aa75671e69eefec/opencv_python-3.1.0.0-cp33-cp33m-manylinux1_x86_64.whl#sha256=41df6dff068a9f78af1e72272798caf8611de80513350c28d919f812b9c60ca8 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/12/5a/f887a88ec8e15a8156845ede1165b0a5cd9bc29330cf2a81e72cbd8e04a5/opencv_python-3.1.0.0-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=94a21665938e3d828c6c27669a40a86cfeaac6054435d24bd573e31785c167ac (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/31/12/86a81d99a25ce06d92b509d44c61db58c34bf54220a2158ea9a37dd31885/opencv_python-3.1.0.0-cp34-cp34m-manylinux1_i686.whl#sha256=43189ecbb3bbae2cc91738b324846b8998db585b6c2dfaababc4f07ade38439a (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/1c/e0/beef33b87bfe58805ae61b044ffa73115b23d8a3861e27da449d674e5c21/opencv_python-3.1.0.0-cp34-cp34m-manylinux1_x86_64.whl#sha256=7f73d5a238a53930a2c69385d4089060e82d11c2382bb89c32dae8d9c6f8d1a4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/ac/0f/2a1337eb913af9b74bf388b619da38d145e1ae55afc5c9ddefd0775078ac/opencv_python-3.1.0.0-cp35-cp35m-manylinux1_i686.whl#sha256=21f45ae89fc3058a4cde3b55fa28a32e2b77c5c845129ee94bf5ea93c304c60d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/09/41/262e350450a256e2b170f86ade97e545318eab3cf267b0e80e3d48d29765/opencv_python-3.1.0.0-cp35-cp35m-manylinux1_x86_64.whl#sha256=f7a580f109b4c74e929ac5116204a9745920b330b5e953d848187df692175f1e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f4/b2/0016521cac04dfa5a3fb54c129ba0cd8748c6f433510bcbe36f9702effbe/opencv_python-3.1.0.0-cp35-cp35m-win32.whl#sha256=a92fd10afe4ff7f082e01abd5f461becf62012e6f2a6a679482f732bacb9fc13 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/e9/67/a0112fdb70f67bb8f3fa3f188ce6f684830b5d4c0e1de7abb9f1b24e5d1f/opencv_python-3.1.0.0-cp35-cp35m-win_amd64.whl#sha256=411210f5ee2bd403c891230aebfba635e9537bdf7999e2352cc38623e092e375 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/e3/d9/780ceb3ee771c42885ec3a8274aa25ef8e5f7e0dd5e933d3ce369ee43d80/opencv_python-3.1.0.1-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=8ea88988917f0691794d5d20b27c2bc801e2dcdd6dcd385fb65bb62a18ebf01e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/a8/6f/f41cd08deec1cbe7e49f8192cf62d7db2b36c447a11dfb15d51ffcd7fc89/opencv_python-3.1.0.1-cp27-cp27m-manylinux1_i686.whl#sha256=9fcf3a99393967088ed0338052975a2289b1780b9f291661857969e715cd5902 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/59/3f/bc7d8e380ba2b6f846bf5dc5789b4494af2f1d509a39ef2ee1074f7a64a2/opencv_python-3.1.0.1-cp27-cp27m-manylinux1_x86_64.whl#sha256=a25eabef6baa721848673792a855e1997c29ee5d70e9a422f5f35e3a0aabe47f (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/75/87/bd558d8d98e664665c04c339396e620474348a80e225f5dfe85d3f376387/opencv_python-3.1.0.1-cp27-cp27m-win32.whl#sha256=1839c1d24df5912210a8a5b61c52910281977642b7795e010fc16b2b4417dcf4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/f1/59/4e17b8ec32b690cef065b1db1c8ab8ba636d6a5f63b97c064872bbf2e00d/opencv_python-3.1.0.1-cp27-cp27m-win_amd64.whl#sha256=c34f88cd901c4b0d564d61b14245aa63c95e018ded64a901e40fbf58dc1826c0 (from https://pypi.org/simple/opencv-python/), version: 3.1.0.1
#     Skipping link https://files.pythonhosted.org/packages/b6/7f/44ab135893c7a85aa8eb9089dd202ebb7f13155cd377ffef8eb73aae7994/opencv_python-3.1.0.1-cp27-cp27mu-manylinux1_i686.whl#sha256=775027ff39f9cbeffbf30b2dfd235074f14829d3517335d02f5d4abef15560d9 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/df/9c/2e4aa3457c3854633bc23e5e1b18d29dad864d155d4ed1a0a8f60f60ad1b/opencv_python-3.1.0.1-cp27-cp27mu-manylinux1_x86_64.whl#sha256=660b7b1d6fe108bef4ed3379248a97f176d6606f00f66f36979ec2edacbba512 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d4/8b/e22e3a044a1ea01cffdfb292eeca0c05015d17422707ea2cf7189466cf84/opencv_python-3.1.0.1-cp33-cp33m-manylinux1_i686.whl#sha256=421c0af06aa26b2ab4b535519bc0a50e022d2b95413199ea254d8b67b109408e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/98/77/87abb945b919b489bde6bc4bff7e6046a6c0548ab60c8a87634617d0e9bb/opencv_python-3.1.0.1-cp33-cp33m-manylinux1_x86_64.whl#sha256=b7c63c5cfd91cfcdf7592012ffd6eed37a96bc6db8338eae2d7ef66fa86a825c (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f3/04/1f24af55d17ec9e441556ee9760b2abd4fedc2d028dc55802ae52b93d2fb/opencv_python-3.1.0.1-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=007cd13d7044fff8c9d78596d32094f83e301022332a1bb684a92940de66a182 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/5d/0e/513c5f83bbf69618d6d3154518276f008a2b04fa87569cd390484abd795a/opencv_python-3.1.0.1-cp34-cp34m-manylinux1_i686.whl#sha256=4b00d1718482a631e2c172b3cae60a7c0b7dc860243974c74f2a7300651c1eff (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/ea/13/73b899511684a65eba3d05b430ee7a65c66e7ad9015e0b4344a2880595e8/opencv_python-3.1.0.1-cp34-cp34m-manylinux1_x86_64.whl#sha256=f5a7d264a07aed3b7948c289227870f598b7ba882e3b7771fdc55309f2a898d4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/57/e6/5b34792061cc21e7a1368c3435629d6e3fde8e72395c1891f9e084a9d257/opencv_python-3.1.0.1-cp35-cp35m-manylinux1_i686.whl#sha256=d2e3c309b6b216b05ea6c12134a5a10c09c59d56fc9e8d99414acc81699e8e15 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/27/56/c4b61b37cfc9020fbc562f4e8230687177cf5bc7fc48af2458de58005cca/opencv_python-3.1.0.1-cp35-cp35m-manylinux1_x86_64.whl#sha256=c29056efe78b5aded17f5e7dbdb5584040a385611de465284196f3fe314c3e28 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d9/b9/bd22a68fe77a5be618d955e2a4da90ee52144edddc0332e232511245fcd0/opencv_python-3.1.0.1-cp35-cp35m-win32.whl#sha256=a5f7327a8c7cad374728cde27baa32c9c490c8ff212e1aaf97c43cbd2552809e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6c/a1/c1d423f142e447d62fc7b52a4581eadea4bb1ef7b9725b751c1e18abf882/opencv_python-3.1.0.1-cp35-cp35m-win_amd64.whl#sha256=cd3ff53da44433f4d56f39f8f0359a88378272662de16783f6d33a2e6a742e00 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/26/8b/76070599f59786a1021ebe6f5b2eaa19dc45451c069425c9246b46b65d9a/opencv_python-3.1.0.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=61d998bf76c6a9f0285d35e237fbb6f40b7963435779ae7d7f23a32e0974d8bf (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/0e/8c/96f713a9528d1b22359d63de9c622a2db7fbe9d5231b4894ff4c118ced42/opencv_python-3.1.0.2-cp27-cp27m-manylinux1_i686.whl#sha256=068759672a064ad2ce3b67420a1847eefcc09b693970888e8c3f5f68d5c0b21a (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/79/cc/5da7f3152a8b194fd1e0b6dde8b8ebbef4eb94d1b2237348ea55bf714e50/opencv_python-3.1.0.2-cp27-cp27m-manylinux1_x86_64.whl#sha256=64c9625d44822a9cda361acbe2a6e3b26668ccbc1404df5b1c4c7e989f7298e4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/7c/3a/79c62965efdd4193a247f3fa2a0935f539a9475f03c6a747be0cc007915e/opencv_python-3.1.0.2-cp27-cp27m-win32.whl#sha256=aa0e6e85676c47086d48fd8b8f3fc20e20209fdae374ecb08d4a9b1cc3f1808e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/fe/53/b6fc038b69c9b139dc6e4a95f970c2f5fd5af7bcb4be91ff043ff7e2c3ab/opencv_python-3.1.0.2-cp27-cp27m-win_amd64.whl#sha256=62e8068c776166417f80b2d0c8757fe78e322cf18dbf76cc0beade81200c9fbf (from https://pypi.org/simple/opencv-python/), version: 3.1.0.2
#     Skipping link https://files.pythonhosted.org/packages/d1/11/b47aca116f6ef39558c1d3ab1b373e3ed5612cb39ef5e1b49dc0f2e05d9b/opencv_python-3.1.0.2-cp27-cp27mu-manylinux1_i686.whl#sha256=d00dfa00d8c2d91fa592f768c996402df9007d89198fde8446afa69e6e35e368 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/cd/04/08f8703ccef745d3f61d8310ef2e0a44d273aae5287e69dcc2a216725f0a/opencv_python-3.1.0.2-cp27-cp27mu-manylinux1_x86_64.whl#sha256=94a16ebe92ae461551b0d4b978e16207da666bae4ea74415c0415a17981e5e81 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f4/35/095ab3a027474d8816786e7368c36d90de8d954954b3d63bf982da8c84fd/opencv_python-3.1.0.2-cp33-cp33m-manylinux1_i686.whl#sha256=1b90bc8742b1cbfb772e1044255cc26e69ddc4d3f610ddbd35e928da1f69a9a5 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/58/73/206c741be61db82eaa1c86073db1615a1eff76579ed44ee73fb812324582/opencv_python-3.1.0.2-cp33-cp33m-manylinux1_x86_64.whl#sha256=ee73f7826324aefae543ff97d347f9c3292b271a4af39281ba98bcc368d0bd4d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/60/b5/84aec8aa5fa080c23b6a52a3b68eb77611066fd0e8d35fcff989ed5920b7/opencv_python-3.1.0.2-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=c3bd28e52bf4502af50e69f2840b1aab608e877eaca44311c4f690dd78ef6687 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/83/bf/7cb49402d086838ecabc836a3efc233ff45838930261e699643d04c91583/opencv_python-3.1.0.2-cp34-cp34m-manylinux1_i686.whl#sha256=cbed39a97e227a4d862ebef54f56c9581d41e4c3663d253dee0c1269c8ecbaa7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/fe/bf/594a41a49c883ab6f8e9d8059775a4fb272f5ed13da03e0581c91f572914/opencv_python-3.1.0.2-cp34-cp34m-manylinux1_x86_64.whl#sha256=cc3bffdc4a94df858efb26079aab5872591065e8a3f71d5dddddf651ba11f2d2 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d4/41/d6529dd2b8d620bcef5e812608c0408dda5d59cd0a41086c4aa762df8fb3/opencv_python-3.1.0.2-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=cd2e8625f0d2dca00f35555fca538bbca43461f2ca80e0ec0855f7e72357f0f7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6b/f7/ed9b0e0de55a35e7c135d921c389248e1e35a0fbd1d898ddd31122f7b681/opencv_python-3.1.0.2-cp35-cp35m-manylinux1_i686.whl#sha256=286d2eaadce3ebf7af3e5adb18485f3b96ed3cac4b15d5121e6c7418fd3a7fb1 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/a5/d6/6d5b3bb76172fa353f17e28fd724a07a5864d060145fbb9857aec4e47fac/opencv_python-3.1.0.2-cp35-cp35m-manylinux1_x86_64.whl#sha256=ef9c6c9778ba38bf4150ae78c3ae87ccd77c9a9e95f80d5fe3dc91fe9e259137 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/29/1f/8eb74172b930eeb809eaffcc734d3f4a1054e03b7d419b043ff762142ba0/opencv_python-3.1.0.2-cp35-cp35m-win32.whl#sha256=86e94ea22166ebf4595c1417551c8a77efa9c12c8177fc6b0cd88d6dc4d5706e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/95/b1/b45c8b0ce1654eb3d2dd98a092d980b16dff996b92ef79f261498304eb49/opencv_python-3.1.0.2-cp35-cp35m-win_amd64.whl#sha256=47f63124e5db870cf3adc0fe9c475007aa0f3165d315bbcfd27ddcb3671cdc0c (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d5/fc/ef79c26e7d15f025921a9f1a722ba467eac13be81bf85f3e3d2435ee399d/opencv_python-3.1.0.3-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=2ad761519b7c41c03a12c20e905b24808420b8267df4436f336fd39d3169e566 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/b0/3f/eba15d71417b0e9d53b505647cf37e89754675a0b359743385c079dfbf8d/opencv_python-3.1.0.3-cp27-cp27m-manylinux1_i686.whl#sha256=29ddd6dbfd210ee94076041f2209aaeb413d6669bc7d370175bb25600240833e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/26/51/543fcbf171ed74ad9eaea8ccf3783ecd235b5c0382e3b8f73cfa62bc2272/opencv_python-3.1.0.3-cp27-cp27m-manylinux1_x86_64.whl#sha256=2487cd3b669518a6c159d39b39f57656c42e3873030d5490d9fc0c5b5c8709f0 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/05/a9/983e4cd67b10232fc3a692636ad28e46e4efb5f5b6fb9f3b1794ca51c6d3/opencv_python-3.1.0.3-cp27-cp27m-win32.whl#sha256=fdd3add5a9258a3a2867f22220e0fe0eca6f570ae56102d47c8285c9ff0a7baa (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/3e/cb/42b688c66b9470b9dad1c726fef299edd206c5e8566bb4b3cf8f00848a82/opencv_python-3.1.0.3-cp27-cp27m-win_amd64.whl#sha256=0380e7a1ee9123cbe7c2faa9c3e59b1361b9c411cb5da0870e8e849895665560 (from https://pypi.org/simple/opencv-python/), version: 3.1.0.3
#     Skipping link https://files.pythonhosted.org/packages/96/45/2522b883905781772c4f0e0465852f274f9b228444ceb52777d6f9bb0197/opencv_python-3.1.0.3-cp27-cp27mu-manylinux1_i686.whl#sha256=b9199e4c99939f0b7c0765076dd333b746312dafc6a2022711eecf58e909fcf6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/14/fb/85915ac0004a34fc6a027ba0b742a86bdc501d16349be5525c773cd16a56/opencv_python-3.1.0.3-cp27-cp27mu-manylinux1_x86_64.whl#sha256=a894e9b6adf322861fbc6f2a7a89ffc27700845d4c76b41a3161595abb5921e4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/8a/6a/62ebf75775b19a5a848203cd5941332aee9da43f9030c18756739aff8066/opencv_python-3.1.0.3-cp33-cp33m-manylinux1_i686.whl#sha256=b128024e8e2965093e61c2db48cf8f7195d072dc87929dd04cee393a157652fc (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/79/4a/535981563448da8bd3b7da4ec83089d85b1570727cba1efc856e6efc1164/opencv_python-3.1.0.3-cp33-cp33m-manylinux1_x86_64.whl#sha256=2f52c8919afe1fde319d094ce6e55257c321a961ba244263c67e5773b304f094 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/32/0f/951d28a46292331e856f67f38e1ea72ca30f54c45235a1c71f59b2ed23ed/opencv_python-3.1.0.3-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=6f8916e7fcdfa9fa8eac4ec800e1512f699616548ce6698bdfd7c150a6f881f5 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/a4/c2/958480837572e6115a33de995d0fb72f1ae494957c98fecc82f957177117/opencv_python-3.1.0.3-cp34-cp34m-manylinux1_i686.whl#sha256=212fdfbce762293dc411a5b774d25443d74464f1295b2ffaa7ae18b12f6a9d19 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d4/90/186a0f8965afb4edd0d6245efdcca9190c7c5ab89ca331813e01b6ffad7c/opencv_python-3.1.0.3-cp34-cp34m-manylinux1_x86_64.whl#sha256=8b1b903a108da6bdbc274973199c9c4612e1880aa5fd891250715591cd0f5878 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/a8/32/7f39629232f86c7ba32f92fe53e11d8257b1ce6236a1402b5ad36f113c8a/opencv_python-3.1.0.3-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=7d680436462198cd7aa939b4c5bf2bb4b3d36ebe8aee31045ff56c69da850c00 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/fe/c7/bc3f8de14c7859ecb2b761cf02c8375f7978de6291af59d0550703fc191c/opencv_python-3.1.0.3-cp35-cp35m-manylinux1_i686.whl#sha256=e7d5eeba14f50115531ad98242d4b0a067a4f4d792a1689598307f4e7bbe29ea (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/63/e2/a92863bc0e43dda51467b333584a47ed7a52cbf24c97c4bb8a5dbf6ffd89/opencv_python-3.1.0.3-cp35-cp35m-manylinux1_x86_64.whl#sha256=11edd751cbfef543d2d0bdc90e1b7356cb8b58a296c7b460d964d0a07df6fd60 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/62/f1/21b0baea0e89b9b6bfdc6f8151a2e53d6093a4bc36c0ed5b9c29632de812/opencv_python-3.1.0.3-cp35-cp35m-win32.whl#sha256=3766feb24bdb3fbc62fcee0224fde9949e9f97111897f762fbdf2c358ec5d03d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/b5/6e/8861dad54e4c1b4d80052e6235dc325db9f27a708fbf094cf29c5548f40a/opencv_python-3.1.0.3-cp35-cp35m-win_amd64.whl#sha256=a026d77f4c61889a4903ee5637fce6b4853ada03aa78310dff740f786645e2e2 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/79/71/df577593eb64eddb6898f9b65a5867a69fd57157db8fc9bfe2887f436dc0/opencv_python-3.1.0.4-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=a1e6d948e4ffa9b7c615eaafe61e6fc98749797c720d4552a10cac8398bd83b1 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/4b/9e/669502aa4003b2df3987d24d85b2fa73749bb3390d00a2488ea06310c49c/opencv_python-3.1.0.4-cp27-cp27m-manylinux1_i686.whl#sha256=17d114067fbd75e470ac383558d6ba2858b061bab143019b0c00dca07997fbf5 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/71/29/11d3ecb4079ee5ba228a26ad8fe609523ba96536c6630eecee9a26e99f62/opencv_python-3.1.0.4-cp27-cp27m-manylinux1_x86_64.whl#sha256=1141a035f7777f9b3bf3b81c9a33e51de72d02da72d0f8734ba80ab7b7dd75ad (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/0e/05/842283689ed92bc1d7bc472142c854cdc746c881fc0041d68ddec4a6c3a7/opencv_python-3.1.0.4-cp27-cp27mu-manylinux1_i686.whl#sha256=8740ed18492dd0f7aa0a7bac1010e46e5b51997adb463390a783372fdfbc585b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6d/a5/c732b18fab788b7bc35b15aa28f529d3d9116059399d4b6741dc77a7f341/opencv_python-3.1.0.4-cp27-cp27mu-manylinux1_x86_64.whl#sha256=f28b848f8d6bb2bca7d048fa54b8ed5ec32b81c8b11524e42b9b20eb88e3fca6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/5b/f8/a6dd0c2ae5e424c07bb24abdf2118589ea3d6fee92eff1c1137a1eb18db8/opencv_python-3.1.0.4-cp33-cp33m-manylinux1_i686.whl#sha256=7b6fd40486b82775c76a26fb5b8d2683cd5b3bed69be04a5859ce8cc53d2d387 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/73/20/ea01f5c3220348605264286de2b974f742cd884ec4f5e2a0d540a2255f29/opencv_python-3.1.0.4-cp33-cp33m-manylinux1_x86_64.whl#sha256=abec2baec030abb398a163f9af2bb2cd982260042cbd954931a1a847f9adef07 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/dc/d2/057bef6358098775577f0f4db4163a4da6b4c820e6597bb0c3ea6c6b97a7/opencv_python-3.1.0.4-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=997141ef13d081bab52570806fdcfd6430a0e49dbf7f47b82d34097adcdab478 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/cd/55/be34a4b8928d8d73f1aed260554ab38d1cd6d1660fde9d5b4b94c2b13b66/opencv_python-3.1.0.4-cp34-cp34m-manylinux1_i686.whl#sha256=f570824f66d348f6e8d09ccb358318a0e1912cc64fbe6dcc1e5c33c73a6c3adb (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/90/82/71a541b9b73cba234e96678e6a214bdb4a606a0140784c96bc62a3086a7a/opencv_python-3.1.0.4-cp34-cp34m-manylinux1_x86_64.whl#sha256=ed95c545fee597fbca16b45329d7168d0e79ae84dd7614553912a0d47b406409 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d5/77/1e63428c9194b4b4920ec545b4069470cab57df1c358579ed9e4c9655067/opencv_python-3.1.0.4-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=868fdc04932c2646a3f3b842438c46aec7f281f4af6487e57b037314e6dd7a4b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/04/cd/ebf54d8da6697441141bba7da6718d2c6bfeab7f6d906601f574c9f44081/opencv_python-3.1.0.4-cp35-cp35m-manylinux1_i686.whl#sha256=04fd740332c3df4a26748011d874e4ed86b0081e25f66a645c573a24f7dccd0b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/3e/10/dd4e43cdbc0e9cec8d43b4073e23e143820b869c91e31d899edf7b78f152/opencv_python-3.1.0.4-cp35-cp35m-manylinux1_x86_64.whl#sha256=7abcbefa9a4ede3099d5b60a7025b0c77fdca39178ee79d80849a83493bef450 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/eb/f7/debaa3ef4e51621bcfd112cf3bf83f0ecb7aaebe67e760f4b3ccd3165d76/opencv_python-3.1.0.4-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=c35f086f0ba144e7389e8ef1f0f16962f98a910f47c148c2a27cd2fa22400aa2 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/63/70/ce715577263ac295b461d9c139b2782cb0d289b75160361bcd75e343e4f1/opencv_python-3.1.0.4-cp36-cp36m-manylinux1_i686.whl#sha256=f888b04c35a3cecd32b2fdc5c47f47884d6fbdb4ca034eac311337478c1b7829 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/4a/48/79ec6689ecc6e2258f38899f092f856901f41a1423121a553e9820de81a1/opencv_python-3.1.0.4-cp36-cp36m-manylinux1_x86_64.whl#sha256=15d7d54583d4d4737a2d75ddacffe43d134addb4518225e45dafaa0e6dfb81db (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/c4/b3/2e1eb1d25ca64259de83ea0b4abfac0311ca54ae46a69fdb452cc8d81b54/opencv_python-3.1.0.5-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=e37171edf3ec928ddc24f3931a6520c5388e276735f494fb556b8d13e2d3cb7d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/62/80/54b78884f8c601aeb14a400490a0a50eb742fa96e768b2238f7638dbac39/opencv_python-3.1.0.5-cp27-cp27m-manylinux1_i686.whl#sha256=09fb7298a21c3d3fda168ff14aa847fb903583e2fce9b29b241fd18dc2f0c2c7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/8a/0d/91907c48a4b6d477a141f9d6d1f2d5018c0cadc22ff6fda234ea826fbf67/opencv_python-3.1.0.5-cp27-cp27m-manylinux1_x86_64.whl#sha256=41a851157b262958979a24b63478fe46b33e54e9444a0ae2da301ed13db6df81 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/cb/14/2fd9980e9db68e3e5ed134c1fda7960771fd06ccf417085442dc1fd39102/opencv_python-3.1.0.5-cp27-cp27m-win32.whl#sha256=ae1f64b54e22db86539e490fae40ab4e10aea5ce35d91e22036596f1e7fc5fe7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/30/96/6f27613c194d5949a2e4f9d39b0261698b075535b26da45ac9eda9a807df/opencv_python-3.1.0.5-cp27-cp27m-win_amd64.whl#sha256=70e275a5107eadd4788b3bc5bad1a39067734e7b6dbd0d2beaf53d2efcb2c7ad (from https://pypi.org/simple/opencv-python/), version: 3.1.0.5
#     Skipping link https://files.pythonhosted.org/packages/ad/2f/145a542417cffc97c4923cba7df421c566faea28300a30a60029af77e7c8/opencv_python-3.1.0.5-cp27-cp27mu-manylinux1_i686.whl#sha256=0f7a6d441f46459eeeaa81772d6ef5fe43621bc36989766984bb0abefbca524c (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/33/53/d2c347f23525598c7819dc0b30927641927e06b59459066b1c9bb118f0cd/opencv_python-3.1.0.5-cp27-cp27mu-manylinux1_x86_64.whl#sha256=da373ac49a6f87ed24dd3255b2afb2cc884de6f1d2f70de9704069d79e2a8aaf (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f3/51/98ce70d838dc859047abf7ba967042de37c25fe4b00cbe0f1defc3959cc0/opencv_python-3.1.0.5-cp33-cp33m-manylinux1_i686.whl#sha256=721573c2bdc94c32d3f8399b8b014348bbe03377be33ab83336b8f64159b33bb (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/cb/40/8a503186d1352963cf578a50f5044b0e83235a86dff3d88b614a60d097ee/opencv_python-3.1.0.5-cp33-cp33m-manylinux1_x86_64.whl#sha256=5e0ccc41b7b9e905596a6fb2b6a7e085d0f6933887f5d6136e866b78468d8d99 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/2e/60/eb5e4b480dff272d66a403738efdb439b69e6bd901d759aec839ee1564f1/opencv_python-3.1.0.5-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=1b7d419f82a1f3e120258528b117153563d0d44b2113a52fce7a27c8b38094b6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/a8/3d/580b862a73d4445c397c107839d0e1515c3616180533b53decf7f0464d75/opencv_python-3.1.0.5-cp34-cp34m-manylinux1_i686.whl#sha256=811f067650ac1b6da57912f1ec1dab606349874a68178eb8f93c49eb69ca226e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/c0/b9/a3a57929781333de64388f63ddb3d56d5ad35de39b32edc3bade078cace6/opencv_python-3.1.0.5-cp34-cp34m-manylinux1_x86_64.whl#sha256=fede7f341cc89de13edffe101b099654164dbf96234c4df6d2982df1879727c6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/3c/38/dfb9efd50220adf40280f702892044a07dc3eb6b9dd9011f4cb58e885a53/opencv_python-3.1.0.5-cp34-cp34m-win32.whl#sha256=85dd182b901da453f60333d379cb6430bde08282322d54e15f41ecbbb3d5619d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/53/1a/cf85572edac094a08fd9202de61778417692f1c5b81bd51b336ca432ced1/opencv_python-3.1.0.5-cp34-cp34m-win_amd64.whl#sha256=795c77bce9699daedd4737f32c0f2f9d4980653e84263a3a869347805f462e09 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/52/14/2862ea7a347ebbc9b907486bdac4cb205392432c85047ae9a2b9c0570d88/opencv_python-3.1.0.5-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=f6c6eeab1153c825c2f9752ac4a2df7a2db6bce27b3e3e6cbb72c3f2b525d571 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f2/50/191797c59da8d9e42f46edb64e3e060111138ed147d63d30a22f5063c62a/opencv_python-3.1.0.5-cp35-cp35m-manylinux1_i686.whl#sha256=de0c7cf7efea62269adc8c17f2de8b3b4830061c44f3c6bcc192eb4821f06c89 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d4/b3/a83e08fe8e436508df8c0698bbb789ff62ababaf6496cf1c8765a77be5ae/opencv_python-3.1.0.5-cp35-cp35m-manylinux1_x86_64.whl#sha256=a5b121346faa87038725ab9f510bd8739ed02d16b39dd2628d7bba7d9531f08b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6c/a4/f637c3b906380ca8ec0e011d0b1c24faa732845ae52eaa5515d68996f3b7/opencv_python-3.1.0.5-cp35-cp35m-win32.whl#sha256=a99ca885adc15e14724ec728011b717ca56873707c433d068e308267ff6b132c (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/2a/7e/62a0c0996d3160439ca21af02e47a410cf91817afe3f29c7e66f4613f7ee/opencv_python-3.1.0.5-cp35-cp35m-win_amd64.whl#sha256=30423bb9023a7924dd1de44f0c4f95f8b1c948909886782ea804aa69f6ff80cf (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/df/d4/3a6f61596cc733020f8251a320279c5745636e926ddd4a07f7e501d40920/opencv_python-3.1.0.5-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=9c73ff7923211141899826850cf6c955411c2037040c87b4bc5b9bf24c4dc4da (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/5a/72/9d2eae8863d5a025a4c768917f8f7026592016bbb687c82a448ce89cd132/opencv_python-3.1.0.5-cp36-cp36m-manylinux1_i686.whl#sha256=9dbc13ad3931680d724b8bb71c8ee5ff8c400fb0e8d94c2036901a68b1d25fde (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/41/5a/9c9896c11e0736bf8d1c1cefd6c8e3b818d74c2fb1f48e29347e98e69d8f/opencv_python-3.1.0.5-cp36-cp36m-manylinux1_x86_64.whl#sha256=336b8cbb0857013bd24406ff005cdb0357ab6baed0e182e7237dfe761c29d3c9 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/aa/46/6aa2a5ae3af89111fd193e6ff6c24741bdd05df57392f698cf8d9124b1d6/opencv_python-3.1.0.5-cp36-cp36m-win32.whl#sha256=c0d69417ed975694b0a09dd84078a2881b442405a2b91862a7af9d2c2f474224 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/46/bd/49006531a73f8c920c34f287477732ced79d8bd19c14f2815a682d4c0142/opencv_python-3.1.0.5-cp36-cp36m-win_amd64.whl#sha256=a7e6a59e65c500c9cdd677e723b8aa47268f950758c4a22fcc53a7bf4496aa37 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/16/24/4c0e3d4fc0bde3d7803e6b8f8748f749f569364aa44a891fc4c71ff22b85/opencv_python-3.2.0.6-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=6c5da2bf6a06feb4a3efd18fd7cdd5b835d27c7b988415a39372588a7601b907 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/22/33/0623b0762ca0bd4653d5448615d42d6c3d8042ead7e1570190244c822d1a/opencv_python-3.2.0.6-cp27-cp27m-manylinux1_i686.whl#sha256=02d1f9244d227abe2d42b2b0e8dbf61c0848ce18fb6181636954d8991d2a4726 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/b3/f3/2d82a24ebd8712e402e5b0d851be4ace969b81e5f24ac9fff7346b5328f7/opencv_python-3.2.0.6-cp27-cp27m-manylinux1_x86_64.whl#sha256=a101dd1cc80abeec1998a0643dc67ff08b29655b11f09f295abf26975d6439c6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/91/7e/3d757ffbd29bf0d4aaa54975bfb4a09d45fae54faeadd3b92642ab80fcb8/opencv_python-3.2.0.6-cp27-cp27m-win32.whl#sha256=6cb967aa9b9350d25c3a6b59b3bd6f5dab127038c6f7973eb4925ec31bf3e2d4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/0e/99/3ea3a1d103739d1fbc174239f52721f79a9e61ee922997a96543a0b8fd70/opencv_python-3.2.0.6-cp27-cp27m-win_amd64.whl#sha256=8d8d34c1341e5ab17089f7486ca1ce7be63589995d714e09d1cfa64de88c19aa (from https://pypi.org/simple/opencv-python/), version: 3.2.0.6
#     Skipping link https://files.pythonhosted.org/packages/7d/5f/dc424811c12cb7bd6e877b25b443427ae90683c4aa104d3434a55a306ce9/opencv_python-3.2.0.6-cp27-cp27mu-manylinux1_i686.whl#sha256=81bd3ebc9852a40ec9510fc1d0b1b4e6cb72e978f7ae90ec32ec82c4b2715ba1 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/5f/16/6e1a33722dfe9beae6c65df0366e562e21da09a286dc8c75a87c40e831b6/opencv_python-3.2.0.6-cp27-cp27mu-manylinux1_x86_64.whl#sha256=066dae3051127f5169f9b634959339558a4cea0eb6a8414765a358e10597cd31 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/13/e1/debf375c907569fbcb763736bc7658bf489c14e2db69fbbe7ae1c403f4f7/opencv_python-3.2.0.6-cp34-cp34m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=87fe6b0f55728285c411134e8cc1d1649a2de5ff8d1aa018cd8b0dbff21871b6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/fd/a6/74c458a52e4fb0f7d9c843033f518216aa145fe47cd458d6970240fb5696/opencv_python-3.2.0.6-cp34-cp34m-manylinux1_i686.whl#sha256=f216b3d5ddb5b20bf38b34a680e9cfa28be924519932fe2bc689a594a410fceb (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/de/eb/528a48d9863bf9c91c50306be20b3627fe5da7245821ad7767cc90fbf563/opencv_python-3.2.0.6-cp34-cp34m-manylinux1_x86_64.whl#sha256=6dda70b847fe24cf092f1efda53c221a07635014b08abf55a0a3c6905422eac0 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/0d/a3/c81bbe75e07d2a0c6f60460a98db9e366dd5cf598f44a2e9614514e08627/opencv_python-3.2.0.6-cp34-cp34m-win32.whl#sha256=7972097a30140e199bb415477e7fdc7c0f00da5bd50cb397dd05fa9b4b66bf75 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/14/cb/72e5be3915f84de8ceb87aaf41ef11a5b10926e5a6253e782e1d91b538d1/opencv_python-3.2.0.6-cp34-cp34m-win_amd64.whl#sha256=9f40b9b54601b314de75690159164a4cd04e15968f0b74389f814491c980aa19 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/21/b0/370a3734e15e30c961eb21b4b42c1094deb101483d3982a4b516736e4a14/opencv_python-3.2.0.6-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=61c3edd23e4efc82efd5b0441d6cbe2e10ecf7d400b366abdee397099b255f02 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/c3/4e/d01ae84b5b87fb68f2b5dadef7f3b9d95fb82786544234a8320a5366f44c/opencv_python-3.2.0.6-cp35-cp35m-manylinux1_i686.whl#sha256=fb15f5ea36326ff34b1561cc3c50ebf7b25944a329e6eb984a9b458954dc4c6d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/be/ae/9cfb85c0800936d840c317844ebdf06d47105337db0f06c887c1f07f6933/opencv_python-3.2.0.6-cp35-cp35m-manylinux1_x86_64.whl#sha256=26d56c48687a587d90fe24c6a597d2f42830e11ded89a0c2b4fb669cf723b052 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/39/4c/32cf479eb470f02fdbe2db60a89d26e6fd238d55796dd79f1ad1cd872727/opencv_python-3.2.0.6-cp35-cp35m-win32.whl#sha256=2789987244b14ee87f93fc47fdb26eeeb6ba4d1ee712168cda543ebfbf88adec (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/73/bc/b4cd900c20dd93dc6233fe4a9eb63500e50ddf8858c73a9713422a5fea28/opencv_python-3.2.0.6-cp35-cp35m-win_amd64.whl#sha256=3d3317fed776c80908931276c5fdb37323cd509726314c7147ce4b39214432eb (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/92/9b/6e28adec509037fd148bca35cad359ba9a159afd0a0a2ea5ebafad4eb427/opencv_python-3.2.0.6-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=8b0a58f6fd58a9a7957026ab9a10b1a1dc6f249057df69d9fa4c963b19408614 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/50/56/8e9921da6f711bf2c554b793ac33958f74a9a31dca30d33abe5a6b100159/opencv_python-3.2.0.6-cp36-cp36m-manylinux1_i686.whl#sha256=a4e72ad4e53f559e4c6447ebd43ce113352830328d7c5de9bc7060f603227fc9 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/5d/34/846187bcdc656e3a81b1bfaf0dedc788abceb2d56c9f3ef48fbfe8215c3a/opencv_python-3.2.0.6-cp36-cp36m-manylinux1_x86_64.whl#sha256=fdb8032d1617e9812b1ebc382f16bee59e7daca89f8f7b325ee8dbb0d863557e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/37/77/0eb7cc5453d0ce3f66c0f90ba1deeae43ecb7d97a3bf8ce4438016642b94/opencv_python-3.2.0.6-cp36-cp36m-win32.whl#sha256=dfb7ee7dedf77aa5b43123e7138b47b670662e9ebff7a7664ba8fd99d6c77506 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/bf/6b/b03cc1b2d55ce41d8c8950b811e44dd088f1e77e25e628ff0ac117070d05/opencv_python-3.2.0.6-cp36-cp36m-win_amd64.whl#sha256=5b93396566028be48a878c258644bbdbb50df57a59a8c784232db11131a3fc3b (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/1a/5b/3578c453bd349784497bc467649f2dc5cfb92a6df7115934669790cf4625/opencv_python-3.2.0.7-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=38db0cda3e64e994a4d2a38f2c218810d2cd76a80a0708f69921c28f686db8f7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/70/b9/b460822a94c3efbd1af503d08b85e309620e638a10cf60e1f29e0a25f2d5/opencv_python-3.2.0.7-cp27-cp27m-manylinux1_i686.whl#sha256=7fe7eed6db3b000f552bf9a31157562338b2418a9e416db1a8e148171395f869 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/de/4e/f27ebc5252f59338010c9479ae7e11b1c38e643ba26013eb876acb1deb28/opencv_python-3.2.0.7-cp27-cp27m-manylinux1_x86_64.whl#sha256=826fde5fa249b80fd889ff7ab83c9ac57737bcf8583839fe82cdbf099f7e7c2e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/16/66/ede133228a92d61f7ea0595d33a2644cff3e70af8455fe5bb1f9a426f278/opencv_python-3.2.0.7-cp27-cp27m-win32.whl#sha256=1f5d55c8ef37d8430bd437c1794eb71377f53d8825dae0bf99ba7fecdb3b3b2f (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/95/6c/32ba116f357a7fde6e470218119ecde54e83fede2023e4bc1dc73714813e/opencv_python-3.2.0.7-cp27-cp27m-win_amd64.whl#sha256=3b50ce5dff68f02d38d243bd6f65195039646810ba56c73a744065e59e55aced (from https://pypi.org/simple/opencv-python/), version: 3.2.0.7
#     Skipping link https://files.pythonhosted.org/packages/d0/08/cddd4cd7483ec3b2817e303689739fb718b3b7616fe4b89d37427921ec2c/opencv_python-3.2.0.7-cp27-cp27mu-manylinux1_i686.whl#sha256=69fa034e3520c9cefaa4ea3de5a7633eba71bd111cca884b6c3bfd0ce71c56c4 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/ce/1d/7f50d218b2c26237f30acf5a06e60d90d724f5525c54f4ca0c8643e75b0f/opencv_python-3.2.0.7-cp27-cp27mu-manylinux1_x86_64.whl#sha256=52c18e160bf0634c24efff925f608aa0feadad619eb6512eced2a1983d991390 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
# ...
#     Skipping link https://files.pythonhosted.org/packages/56/99/f0c1bc7d72b4f2a9b728b819f4709a838c5336a5ae5e3bb49313b79c7e23/opencv_python-3.4.2.16-cp35-cp35m-win32.whl#sha256=49084dc9dd2a48432c966968d184dc63bb5d6b5b55637139c2071ed086160517 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d9/f5/2a43474643c73e2f9fc459a2fc95cbadb6243c5be0d5b6949082b7f54554/opencv_python-3.4.2.16-cp35-cp35m-win_amd64.whl#sha256=7ff68768c079a7d4c27ff43a9e55388c05fb52c1024a3952b1a93484d6813b60 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f5/5e/e64974f435060764f4824f6ee5905ae2733506d2214f7802b45537a64cdb/opencv_python-3.4.2.16-cp36-cp36m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=a4948117b29227a76a77d72de1da8da53d209f4959b150564ce18355da9add1e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/b2/2d/dd122781ddbb2e8e2c730851f7dd5121e2ae055aeee14ed8714882f750ac/opencv_python-3.4.2.16-cp36-cp36m-manylinux1_i686.whl#sha256=5c181a07d9e6800265ab2d89c41460b4849e02f4b387694bcc8d447a1b6ae311 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/fa/7d/5042b668a8ed41d2a80b8c172f5efcd572e3c046c75ae029407e19b7fc68/opencv_python-3.4.2.16-cp36-cp36m-manylinux1_x86_64.whl#sha256=d75f60baced5086300a19c8ba63e75d059e8dce333795ef02084b9be6ec61516 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d5/dd/5373ffa2948bfd619759da483f2499c6c014cff9017125bddd01225a8de5/opencv_python-3.4.2.16-cp36-cp36m-win32.whl#sha256=e416bf67b7c040444a2f6fbbfa77204d79ce7ef87ae7a92f21522089a280edf3 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/eb/6c/c3e960a495dc7ac5f542cc5a8cc177a218aba30aaed2b0d55c1dc5c1693d/opencv_python-3.4.2.16-cp36-cp36m-win_amd64.whl#sha256=2d4d7456dbdce221db8313f95d94d5f26d29b495a6bf9b71537e83faef8a2435 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/eb/28/dfa1d33d8985e4afe26f5deaab3d1b9bfcbfb2c1460c3a088136a090d8eb/opencv_python-3.4.2.16-cp37-cp37m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=fcf2a9bf52261db8ffdd5d33a29a1bbdb3b98a43192d7d3e8ad782a0ec14e51a (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/eb/32/a11beeb5840e559fd8bb7a0af3f0c4de3d1f5d889c5d52df7cdb063f2849/opencv_python-3.4.2.16-cp37-cp37m-manylinux1_i686.whl#sha256=2f324567f9506e7d2df2da24505af3cfbb47c50eddad9217aa37afd5db445608 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/4d/a0/407d74b867a1ad23046719dee784181a9bcdbda22f25d3681d032b8153f9/opencv_python-3.4.2.16-cp37-cp37m-win32.whl#sha256=85366eca1b5a7b67d44913d363b22468eb5760a239cd2d2a04451d1b7f9324cc (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/bd/c9/364f02bb1d2186405995dbb2b579f3c55b68134a9513a7068e0cdbaeb928/opencv_python-3.4.2.16-cp37-cp37m-win_amd64.whl#sha256=b0f8c8a17514960318881c539d462eac3c2a8c307e7cf71454bd407ba408f496 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/ae/f7/01fc83414fbdbb470d6d77ee4a0fd32234046edc4a2e4f7897e3e95ee666/opencv_python-3.4.2.17-cp27-cp27m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=4f0a5c098aad4df88ce7dc3828a857921368635e3a961e80431e60f3522a99be (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/05/46/e772d181f59f0b482c542ffcee137e4c1bd866129d2e8d6afb9c78c07206/opencv_python-3.4.2.17-cp27-cp27m-manylinux1_i686.whl#sha256=440a093dda50daf093d73aae2dd333c9e4a593cfe7df8cbc298b421d313e263f (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/0a/5e/a28eb882e43e73e5afb8ed71016085b02d07a6e9b2bb8c01e3ada43ed04b/opencv_python-3.4.2.17-cp27-cp27m-manylinux1_x86_64.whl#sha256=2306ddd98aa52688c9667f8080349d653d465a2b838cbacb19561286046ba1e8 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/bc/88/ac77b7f65fe6118b77fc0f18dd234a5c5a600406546c9343aeb288ff038e/opencv_python-3.4.2.17-cp27-cp27m-win32.whl#sha256=78390d93834b6b7c9d9234dba68ba9c34a966f60e519efd2691e5c367dee7f8e (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Found link https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl#sha256=1f7fa5433c26c637cf923c59025df12fcd56b2d205da178c7ad6954e6e50912e (from https://pypi.org/simple/opencv-python/), version: 3.4.2.17
#     Skipping link https://files.pythonhosted.org/packages/02/03/0360fc077ae1f9d3bfefaf6f081a895d9ff28b6ae342a9ecdf0878230e98/opencv_python-3.4.2.17-cp27-cp27mu-manylinux1_i686.whl#sha256=31945ea9e7324c41be925f2b21fcb523844b2399dc649010f3a3e97825dcfcd0 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/60/6a/dcc146a95bc8bde469958ee3ae693a8721798c5f9da7ea58e5a580754610/opencv_python-3.4.2.17-cp27-cp27mu-manylinux1_x86_64.whl#sha256=4b5902b647e66addfa5218dbc75e7a4de2f46c253ea17b234408f5792cfc8d7f (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/3d/78/e164fc51c848af97b3a09a94b5f9876f1eb8016684f33518423fa4463845/opencv_python-3.4.2.17-cp34-cp34m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=c672596fa261766d6d0cc02377755558b92dee80a64ee8dd6f58f4e56bf7835d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6b/59/307f4379b8af53a8d1d13b7a21e7c5d9eb9594a062797eb3b4fa11752db8/opencv_python-3.4.2.17-cp34-cp34m-manylinux1_i686.whl#sha256=81519bba8560c68f587482c157a74cf04d5a2877d4367377d2671e66eb7a3961 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/62/f7/44a6c7e2806a4c4c6486d0e55c88c26b80b396b6f4915a61194b330968c4/opencv_python-3.4.2.17-cp34-cp34m-manylinux1_x86_64.whl#sha256=20bd10b6f6f5de1a5e796900ab77ea57366139290f426d2039d3919d8ddf9f1c (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/20/3b/649384046207488f6a76eaf512b269e621cfc2a39dbdbcfff76e49ad5757/opencv_python-3.4.2.17-cp34-cp34m-win32.whl#sha256=fd6ac9a11faa5d1cbf014d059dd890ad6f0583f149e780ff7d0d3d47e68438d6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/87/c1/9fbe259bf42e7d59aafdde03fe595fb820d860ac4555b66f0932fd21ec62/opencv_python-3.4.2.17-cp34-cp34m-win_amd64.whl#sha256=1f035595ef2f296c234c2b8b9659162646b9312afd0cec7ab0217bad915ff068 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/18/88/deef99a51e6a8d202ee79900b92cc3739b35663fce195ed7f95f367f2438/opencv_python-3.4.2.17-cp35-cp35m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=70f3c6fe31af7c00c60cb91bb7351837ba6c7b3d173b855ca5dbe265b90a1606 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/e0/2e/7c9ea28132afdc21921c7890c6917095433515161be4ff04fa583af9bc17/opencv_python-3.4.2.17-cp35-cp35m-manylinux1_i686.whl#sha256=0dbbd0348c8282d4e3cf472a8e2a17785f05c22a55647253fa00b539897f8fcc (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6a/c8/32023281fc27b787f966a33b8ae946b0f3491062e8b1f1e48029f0269a0d/opencv_python-3.4.2.17-cp35-cp35m-manylinux1_x86_64.whl#sha256=36680744ebdc66a9da0a65f1f33ec9cf5d26a98749c5701dc612b334b213997d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/2c/8b/f47ecc4765a36f60d9a6735e015502f674bc072ab0ac4fd9e301f314a9bf/opencv_python-3.4.2.17-cp35-cp35m-win32.whl#sha256=a354096290dd57ddb2664e7b21ddb6c6c2f5297cc4d8a402ce3f6a82a24807e3 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/34/60/a8feee857c5e610f16e4a2584e0554156c55470697efc23c0162b712a5d4/opencv_python-3.4.2.17-cp35-cp35m-win_amd64.whl#sha256=a4635e22637181b478d6ad337c94b596c98c16bdbae92ef90514bbf31e30ef3a (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/6d/c5/75c453e9ee142e884871ecb4a5c086ae8f0d95f7aa88e8a329dae9c2b9ef/opencv_python-3.4.2.17-cp36-cp36m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=b23359c21c4eb84f28fbe1331723bbf1ebc34125f22480da4b16cfae989a3249 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/58/35/3331b03d43e82e4c529d9eb6aecda396ac8cd9bac80093502098185fb133/opencv_python-3.4.2.17-cp36-cp36m-manylinux1_i686.whl#sha256=6e4fee2ee2bc4d911dad78e2b167da97796879aaade4be3ff42ff1993e250b15 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/53/e0/21c8964fa8ef50842ebefaa7346a3cf0e37b56c8ecd97ed6bd2dbe577705/opencv_python-3.4.2.17-cp36-cp36m-manylinux1_x86_64.whl#sha256=6df586230f9146afde5b8e2f4511978f8fb6172bf0f47ba290423979baae974d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/d6/ed/82bdd13948f39565647d15e4ebbda3ca8bcf3e7cb81cca8920bea81ddb7f/opencv_python-3.4.2.17-cp36-cp36m-win32.whl#sha256=4b0465c3df9dea074583b6b4f8cf22e5902c5c5ec213a479c6c834a8a0191cf7 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/f2/f8/42f3ac356fae2500148b7a64b55169212d841987141a3f730708ae128cee/opencv_python-3.4.2.17-cp36-cp36m-win_amd64.whl#sha256=0495e9247fbbd5d88346bb4d480df27fb4000aa4799b5a15b1735968a94a5189 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/90/09/faacf0d3acef207c4fa5c54582699f2e9f7546a8f27ad982525aceedba4d/opencv_python-3.4.2.17-cp37-cp37m-macosx_10_6_x86_64.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=078e8ea34d06b3fa459c58a6ce966ef715cc2e913b7bd96a46beb345975aa5d6 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/12/e9/77733283f1f9b9f68317cbc2ea15dac50a74b5ccfd4e28eb194dd13e5430/opencv_python-3.4.2.17-cp37-cp37m-manylinux1_i686.whl#sha256=409e3a4c925accd68a5ab1cef21dd04b957c0ee2985db8f075a808dccd6e0f73 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/8f/8f/a5d2fa3a3309c4e4aa28eb989d81a95b57c63406b4d439758a1a0a810c77/opencv_python-3.4.2.17-cp37-cp37m-manylinux1_x86_64.whl#sha256=87beeb6ad4ffcd6fbfbb464a8a75c7a1389a0642cc632ecceb504c86139567e3 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/9b/fb/2d64096443465587abeb223019705ba01e265bb77813b94129716df6786c/opencv_python-3.4.2.17-cp37-cp37m-win32.whl#sha256=ba52829eafab59c5260bec012fad0e26bd05389828af0e316e278912c82dab32 (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#     Skipping link https://files.pythonhosted.org/packages/20/f3/90410344a0d68b9888e64b16152807c33fa5a8eaefd3beb18d88eea62159/opencv_python-3.4.2.17-cp37-cp37m-win_amd64.whl#sha256=1b302b4721ca2d55ae7e9e80acebd73499c16a82be9bebc563a7937dbd348b2d (from https://pypi.org/simple/opencv-python/); it is not compatible with this Python
#   Using version 3.4.2.17 (newest of versions: 3.1.0.0, 3.1.0.1, 3.1.0.2, 3.1.0.3, 3.1.0.5, 3.2.0.6, 3.2.0.7, 3.2.0.8, 3.3.0.9, 3.3.0.10, 3.3.1.11, 3.4.0.12, 3.4.0.14, 3.4.1.15, 3.4.2.16, 3.4.2.17)
#   Created temporary directory: c:\users\davidb~1\appdata\local\temp\pip-unpack-2jey5g
#   Looking up "https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl" in the cache
#   No cache entry available
#   Starting new HTTPS connection (1): files.pythonhosted.org:443
#   https://files.pythonhosted.org:443 "GET /packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl HTTP/1.1" 200 33765209
#   Downloading https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl (33.8MB)
#   Downloading from URL https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl#sha256=1f7fa5433c26c637cf923c59025df12fcd56b2d205da178c7ad6954e6e50912e (from https://pypi.org/simple/opencv-python/)
#   Ignoring unknown cache-control directive: immutable
#   Updating cache with response from "https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl"
#   Caching due to etag
#   Added opencv-python from https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl#sha256=1f7fa5433c26c637cf923c59025df12fcd56b2d205da178c7ad6954e6e50912e to build tracker 'c:\\users\\davidb~1\\appdata\\local\\temp\\pip-req-tracker-u4ktca'
#   Removed opencv-python from https://files.pythonhosted.org/packages/5e/2e/755cf0e164afad495f1e7f18afaac3ac96131addc04d478641fc42c0822a/opencv_python-3.4.2.17-cp27-cp27m-win_amd64.whl#sha256=1f7fa5433c26c637cf923c59025df12fcd56b2d205da178c7ad6954e6e50912e from build tracker 'c:\\users\\davidb~1\\appdata\\local\\temp\\pip-req-tracker-u4ktca'
# Requirement already satisfied: numpy>=1.11.1 in c:\users\david brown\anaconda2\lib\site-packages (from opencv-python) (1.11.1)
# Installing collected packages: opencv-python
#
# Successfully installed opencv-python-3.4.2.17
# Cleaning up...
# Removed build tracker 'c:\\users\\davidb~1\\appdata\\local\\temp\\pip-req-tracker-u4ktca'

# %%
import skimage.io as io
io.use_plugin('tifffile')

#I updated "skimage.filter" to the more recent plural "skimage.filters"
from skimage.filters import threshold_otsu, threshold_adaptive, rank
from skimage.morphology import label
from skimage.measure import regionprops
from skimage.feature import peak_local_max
from scipy import ndimage
from skimage.morphology import disk, watershed
import pandas as pd
import numpy as np #added to morphogenie code
import mahotas as mh  #used for labelling binary regions
import matplotlib.pyplot as plt #added to morphogenie code

from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.spatial import distance as dist
import scipy.cluster.hierarchy as hier
from scipy import fftpack
from matplotlib.colors import LogNorm
import math

# %%
import cv2

# %%
##Try working with a masked array
import numpy.ma as MA

# %%
from skimage.morphology import watershed
from skimage.segmentation import clear_border
from scipy.ndimage import morphology
import skimage.morphology

# %%
# %matplotlib inline

# %%
##Assumptions

#Nuclei cannot be thinner than 2.6um == 10 z slices
#Narrower than 3um == 46 pixels
#Or wider than 20um == 308 pixels

#They cannot be dimmer than background
#Transfected nuclei cannot be dimmer than GFP_background

# %%
#I adjusted the morphogenie code to import the full stack, and then focus on the Hoechst Channel for segmentation.
#im = io.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_2_Box1.tif')

#im = io.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_1/Well02_HeLa_PHD2-IDR-PHD3_1_MMStack_Pos0.ome.tif')

im = io.imread('C:/Users/David Brown/Documents/Huang Lab/Exp0104_KDM5A_PHD2-fragments/Well02_HeLa_PHD2-IDR-PHD3_1/Well02_HeLa_PHD2-IDR-PHD3_1.tif')

Hoechst_stack = im[:,:,:,0]

z_size, x_size, y_size = Hoechst_stack.shape

z_scale = 0.26 # µm per plane for 100x NIC confocal images
xy_scale = 0.065 # µm per pixel for 100x NIC confocal images

# %%
##Quick check
#image_stack = im[0,:,:,:] #for .ome.tif files
#image_stack.shape
plt.imshow(Hoechst_stack[4])
plt.title('Hoechst Slice')

# %% [markdown]
# **Find transfected cells**
#
# Q: What is the background GFP intensity?
#
# A: ~120
#
# Q: What is the background Hoechst intensity?
#
# A: ~110
#
# Q: Where are the transfected cells?
#
# A: Transfected cells fall within the filled_course_GFP_mask

# %%
GFP_stack=im[:,:,:,1]
MAX_GFP=GFP_stack.max(axis=0)
plt.imshow(MAX_GFP)
plt.title('GFP Max z-Projection')

# %%
#Smooth signal
course_GFP = mh.gaussian_filter(MAX_GFP, 10.)
plt.imshow(course_GFP)
plt.title('GFP Max Gaussian Filter')

# %%
##Threshold
course_GFP_mean = course_GFP.mean()
course_GFP_mask = course_GFP > course_GFP_mean

##Remove cells on the border
cleared_course_GFP_mask = clear_border(course_GFP_mask).astype(int)

##Fill holes
filled_course_GFP_mask = np.array(morphology.binary_fill_holes(cleared_course_GFP_mask).astype(int))

plt.imshow(filled_course_GFP_mask)
plt.title('course GFP mask')

# %% [markdown]
# **Detect Nuclei**

# %%
##Need to broadcast the 1d mask (here using 'ones_like', to mask the 3D Hoechst stack
##Use np.logical_not to invert, ~ gives integer inversion resulting in -1s.
GFP3d_mask=np.ones_like(Hoechst_stack)*np.logical_not(filled_course_GFP_mask)

# %%
##Mask Hoechst image to focus on transfected nuclei
Hoechst_ma=MA.masked_array(Hoechst_stack,
                           mask=GFP3d_mask, 
                           fill_value=0.)

plt.imshow(Hoechst_ma[4])
plt.title('Masked Hoechst Slice')

# %%
##Find Nuclei

##3D Gaussian Filter
#I tried using the mask, but it was completely ignored by the gaussian filter
smoothed_Hoechst_stack=mh.gaussian_filter(Hoechst_stack, 6.)
shs_mean = smoothed_Hoechst_stack.mean()
Hoechst_mask = smoothed_Hoechst_stack > shs_mean

##Clear border and Fill holes ineffective on 3D stacks

# %% [markdown]
# **Fill Holes**

# %%
##v5.2 - Try median filter right off the bat

##Tight_smooth using (3, 5, 5) median filter
tight_smooth=ndimage.median_filter(Hoechst_stack, footprint=np.ones((3, 5, 5)))

##Mask Hoechst image to focus on transfected nuclei
tight_ma=MA.masked_array(tight_smooth,
                         mask=GFP3d_mask,
                         fill_value=0.)
                           
#Calculate threshold for tight smooth nuclei 'tT'         
tT=tight_ma.mean()

# %%
plt.imshow(tight_ma[4])
plt.title('Tight Masked Hoechst Slice')

# %%
##Generate tight smooth mask
#clustered_nuclei=tight_smooth>250
nuclei_stack=tight_smooth>tT

# %%
##Intersect Hoechst and GFP binary masks to identify transfected cells
transfected_nuclei=nuclei_stack*np.logical_not(GFP3d_mask)

plt.imshow(transfected_nuclei[4])
plt.title('Transfected Nuclei')

# %%
plt.imshow(transfected_nuclei[10])
plt.title('Tight Masked Hoechst Slice')

# %%
##Try with tight_ma

nuclei_stack = np.zeros_like(Hoechst_mask)

## Labeling for each z plane:
for z, frame in enumerate(transfected_nuclei):
    cleared_H = clear_border(frame).astype(int)
    filled_H = morphology.binary_fill_holes(cleared_H).astype(int)
    nuclei_stack[z] = filled_H
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-70bbe9900ea0> in <module>()
#       2
#       3 ## Labeling for each z plane:
# ----> 4 for z, frame in enumerate(transfected_nuclei):
#       5     cleared_H = clear_border(frame).astype(int)
#       6     filled_H = morphology.binary_fill_holes(cleared_H).astype(int)
#
# NameError: name 'transfected_nuclei' is not defined

# %%
##Plot Detected Nuclei
plt.imshow(nuclei_stack[0])
plt.title('Detected Nuclei')

# %%
##Intersect Hoechst and GFP binary masks to identify transfected cells
transfected_nuclei=nuclei_stack*np.logical_not(GFP3d_mask)

plt.imshow(transfected_nuclei[4])
plt.title('Transfected Nuclei')

# %%
##Try labelling first
#Labelling works with 3D arrays, so connectivity is already estabilshed
labeled_nuclei, nr_objects = mh.label(transfected_nuclei)
labeled_nuclei
plt.imshow(labeled_nuclei[4])

# %%
#3D bounding boxes
bb  = np.array(nuc_props[1].bbox)
#zmin, ymin, xmin, zmax, ymax, xmax  = nuc_props[1].bbox
#zmin, ymin, xmin, zmax, ymax, xmax = bb
crp=labeled_nuclei[bb[0]:bb[3],bb[1]:bb[4],bb[2]:bb[5]]
#plt.imshow(labeled_nuclei[zmin:zmax,ymin:ymax,xmin:xmax])
plt.imshow(crp[1]) #Remember the image is still 3D

# %%
#Area in each plane
bb[0], bb[3] #object 1 covers 25 planes (more than there actually are?? because Python is inclusive->exclusive

# %%
#np.count_nonzero(crp[0]) #area in frame0 = 26,693
#np.count_nonzero(crp[1]) #area in frame1 = 26,629
#np.count_nonzero(crp[23]) #area in frame0 = 17,469

#nuc_props[1].area #area given for frame1 = 561,595, which suggests "area" is acctually volume == total pixels
nuc1=labeled_nuclei==2
sum(sum(sum(nuc1))) # gives the same figure, 561,595

# %%
#Watershed nuclei above the upper limit
props=[]
indx=[]

nuc_props=regionprops(label_image=labeled_nuclei, intensity_image=GFP_stack) #18 object labelled

heading=["volume","mean_GFP","integrated_GFP"]

for n in nuc_props:
    props.append([n.area,
                  n.mean_intensity,
                  n.mean_intensity * n.area])
    indx.append(n.label)
Nuclear_Properties=pd.DataFrame(props, index=indx, columns=heading)
Nuclear_Properties

# %% [markdown]
# **Detection parameters**
#
# We usually need some settings, derived from what we now of the objects we are trying to segment.
# We’ll also normaly do some kind of smoothing, which will be specified as the pixel size of the filter kernel. So here we go:

# %%
min_vol = 50000
max_vol = 1000000

#from skimage.morphology import remove_small_objects
real_nuclei=remove_small_objects(labeled_nuclei, min_vol)

# %%
plt.imshow(real_nuclei[4])

# %%
clusters=remove_small_objects(labeled_nuclei, max_vol)
plt.imshow(clusters[4])

# %%
##Tight_smooth using (3, 5, 5) median filter
tight_smooth=ndimage.median_filter(Hoechst_stack, footprint=np.ones((3, 5, 5)))

##Mask Hoechst image to focus on transfected nuclei
clusters_ma=MA.masked_array(tight_smooth,                       
                           mask=np.logical_not(clusters), 
                           fill_value=0.)

#Calculate threshold for clustered nuclei 'cT'         
cT=clusters_ma.mean()

# %%
##Generate tight smooth mask
#clustered_nuclei=tight_smooth>250
clustered_nuclei=tight_smooth>cT

# %%
##Plot result
plt.imshow(clustered_nuclei[4])
plt.title('Tight Smooth Mask')

# %%
##Try fitting polygon
img8 = (MAX_GFP).astype('uint8')
#thresh=cv2.threshold(img8,100,255, 0)
blur = cv2.GaussianBlur(img8,(7,7),0)
ret,thresh = cv2.threshold(blur, 0, 225, cv2.THRESH_OTSU)
#contours,hierarchy = cv2.findContours(thresh, 1, 2)
im2, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#contours,hierarchy = cv2.findContours(filled_course_GFP_mask, 1, 2)

# Otsu's thresholding after Gaussian filtering
#blur = cv2.GaussianBlur(img8,(5,5),0)
#ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

#plt.imshow(th3)

# %%
hierarchy
# Out:
# array([[[  1,  -1,  -1,  -1],
#         [  2,   0,  -1,  -1],
#         [  3,   1,  -1,  -1],
#         ...,
#         [317, 315,  -1, 314],
#         [318, 316,  -1, 314],
#         [ -1, 317,  -1, 314]]])

# %%
plt.imshow(im2)
plt.title('Contours')

# %%
cnt = contours[2]
#plt.imshow(cv2.drawContours(MAX_GFP, [cnt], 0, (0,255,0), 3))
cv2.drawContours(MAX_GFP, [cnt], 0, (0,255,0), 3)
plt.imshow(MAX_GFP)

# %%
MAX_GFP.max()
# Out:
# 725

# %%
##This is the function that clears objects from the image border and fills holes slice by slice.
def clear_fill(array):
    '''Loops through each slice of an array, removes objects from edges and fills holes`.
    
    Parameters:
    -----------
    array: a bloolean array
        
    Returns:
    --------
    
    values: 'stack', an array with the same shape as `array`
        
    '''
    stack = np.zeros_like(array)

    ## Process binary array frame by frame:
    for z, frame in enumerate(array):
        cleared = clear_border(frame).astype(int)
        c = skimage.morphology.closing(cleared)
        cc = skimage.morphology.closing(c)
        filled = morphology.binary_fill_holes(cc).astype(int)
        o = skimage.morphology.opening(filled)
        oo = skimage.morphology.opening(o)
        stack[z] = oo

    return stack

# %%
##Call clear_fill function
filled_clusters=clear_fill(clustered_nuclei)

##Relabel
new_labeled_nuclei, nr_objects = mh.label(filled_clusters)

# %%
plt.imshow(new_labeled_nuclei[10])

# %%
##Intersect Hoechst and GFP binary masks to identify transfected cells
bw=clusters>0
#Use <0 to remove original labels from 'clusters', converting to a binary image
transfected_clusters=new_labeled_nuclei*bw

##Filter by size
real_clustered_nuclei=remove_small_objects(transfected_clusters, min_vol) #After fill

# %%
plt.imshow(real_clustered_nuclei[6])
plt.title('Clustered Nuclei above size cutoff')

# %%
##Filter by size

# %% [markdown]
# **Watershed**

# %%
##Test case
distance = ndimage.distance_transform_edt(clusters[4])
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((10, 10)), labels=clusters[4])
markers = ndimage.label(local_maxi)[0]
labeled_clusters = watershed(-distance, markers, mask=clusters[4])

# %%
##Alternaive using GFP intensity
distance = ndimage.distance_transform_edt(clusters[4])
local_maxi = peak_local_max(GFP_stack[4], indices=False, footprint=np.ones((40, 40)), labels=clusters[4]) ##Using GFP data
markers = ndimage.label(local_maxi)[0]
labeled_clusters = watershed(-distance, markers, mask=clusters[4])

# %%
##Test case
distance = ndimage.distance_transform_edt(clusters[4])
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((10, 10)), labels=clusters[4])
markers = ndimage.label(local_maxi)[0]
labeled_clusters = watershed(-distance, markers, mask=clusters[4])

# %%
##Show the output
plt.figure(figsize=(9, 3.5))
plt.subplot(131)
plt.imshow(clusters[4], cmap='gray', interpolation='nearest')
plt.axis('off')
plt.subplot(132)
plt.imshow(-distance, interpolation='nearest')
plt.axis('off')
plt.subplot(133)
plt.imshow(labeled_clusters, cmap='spectral', interpolation='nearest')
plt.axis('off')

plt.subplots_adjust(hspace=0.01, wspace=0.01, top=1, bottom=0, left=0,
                    right=1)
plt.show()

# %%
#3D watershed has issues with ambiguity it connectivity array
#ws_stack = np.zeros_like(full_mask_stack)
## Watershed all planes
#distance = ndimage.distance_transform_edt(full_mask_stack)
#local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((1, 5, 5)))
#markers = ndimage.label(local_maxi)[0]
#ws_stack = watershed(-distance, markers, full_mask_stack)

# %%
#Process stack
ws_stack = np.zeros_like(full_mask_stack)
## Watershed each z plane:
for z, frame in enumerate(full_mask_stack):
    distance = ndimage.distance_transform_edt(frame)
    local_maxi = peak_local_max(
        distance, indices=False, footprint=np.ones((20, 20)), labels=frame)
    markers = ndimage.label(local_maxi)[0]
    labels = watershed(-distance, markers, mask=frame)

    ws_stack[z] = labels

# %% [markdown]
# **Select Objects**

# %%
##Check the filtered stack
nrows = np.int(np.ceil(np.sqrt(z_size)))
ncols = np.int(z_size // nrows + 1)

fig, axes = plt.subplots(nrows, ncols, figsize=(3*ncols, 3*nrows))
for n in range(z_size):
    i = n // ncols
    j = n % ncols
    axes[i, j].imshow(ws_stack[n, ...],
                      interpolation='nearest', cmap='gray')
    
    
## Remove empty plots 
for ax in axes.ravel():
    if not(len(ax.images)):
        fig.delaxes(ax)
fig.tight_layout()

# %%
##'approximate_polygon' may be a simple way to simplify and smooth the detected objects.

contours, hierarchy = cv2.findContours(binaryimage,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)

for ind, cont in enumerate(contours):
    elps = cv2.fitEllipse(cont)
    #Feed elps directly into cv2.ellipse
    cv2.ellipse(displayframe,elps,(0,0,255))

cv2.imshow("Perfectly fitted ellipses", displayframe)

# %% [markdown]
# **Computing the properties of the labeled regions:**
#
# We use skimage.measure handy function regionprops. For convinience, we store the computed properties in a pandas DataFrame object (this is particullarly usefulll if you have more images or more timepoints, and want to later on manipulate the collected data.

# %%
labeled_stack=ws_stack

properties = []
columns = ('x', 'y', 'z', 'I', 'w')                 #could be cleaned up by adding index as a column heading
indices = []
for z, frame in enumerate(labeled_stack):
    f_prop = regionprops(frame.astype(np.int),
                         intensity_image=image_stack[z])
    for d in f_prop:
        radius = (d.area / np.pi)**0.5
        if (min_radius  < radius < max_radius):
            properties.append([d.weighted_centroid[0],
                               d.weighted_centroid[1],
                               z, 
                               d.mean_intensity * d.area,
                               radius])
            indices.append(d.label)
if not len(indices):
    all_props = pd.DataFrame([], index=[])
indices = pd.Index(indices, name='label')           #could feed into pre-existing column if edited
properties = pd.DataFrame(properties, index=indices, columns=columns)
#properties['I'] /= properties['I'].max() #This will normalise the intensities to the brightest.

# %%
properties.head(25)

# %% [markdown]
# **Clustering**

# %%
fig = plt.figure(figsize=(12, 12))
colors = plt.cm.jet(properties.index.astype(np.int32))

# xy projection:
ax_xy = fig.add_subplot(111)
ax_xy.imshow(image_stack.max(axis=0), cmap='gray')
ax_xy.scatter(properties['y'],
              properties['x'], c=colors, alpha=1)

divider = make_axes_locatable(ax_xy)
ax_zx = divider.append_axes("top", 2, pad=0.2, sharex=ax_xy)
ax_zx.imshow(image_stack.max(axis=1), aspect=z_scale/xy_scale, cmap='gray')
ax_zx.scatter(properties['y'],
              properties['z'], c=colors, alpha=1)
ax_yz = divider.append_axes("right", 2, pad=0.2, sharey=ax_xy)
ax_yz.imshow(image_stack.max(axis=2).T, aspect=xy_scale/z_scale, cmap='gray')
ax_yz.scatter(properties['z'],
              properties['x'], c=colors, alpha=1)
plt.draw()

# %% [markdown]
# Next we want to get the center of each cluster.
#
# To do so we run a weighted average of the positions for each cluster, using the measured intensity as weight.

# %%
##This is the function that groups "cells", nuclei. May be more relevant to larger fields of view
def df_average(df, weights_column):
    '''Computes the average on each columns of a dataframe, weighted
    by the values of the column `weight_columns`.
    
    Parameters:
    -----------
    df: a pandas DataFrame instance
    weights_column: a string, the column name of the weights column 
    
    Returns:
    --------
    
    values: pandas DataFrame instance with the same column names as `df`
        with the weighted average value of the column
    '''
    
    values = df.copy().iloc[0]
    norm = df[weights_column].sum()
    for col in df.columns:
        try:
            v = (df[col] * df[weights_column]).sum() / norm
        except TypeError:
            v = df[col].iloc[0]
        values[col] = v
    return values

# %%
cell_positions = properties.groupby(level='label').apply(df_average, 'I')

# %%
#In this case there is only 1 nucleus
cell_positions

# %%
##Calculate Nuclear Intensity
properties = []
columns = ('x','y','z', 'w', 'mean_GFP','I_GFP')
indices = []
for z, frame in enumerate(labeled_stack):
    f_prop = regionprops(frame.astype(np.int),
                         intensity_image=im[z,:,:,1]) #1=GFP
    for d in f_prop:
        radius = (d.area / np.pi)**0.5
        if (min_radius  < radius < max_radius):
            properties.append([d.weighted_centroid[0],
                               d.weighted_centroid[1],
                               z, 
                               radius,
                               d.mean_intensity,
                               d.mean_intensity * d.area])
            indices.append(d.label)
        if not len(indices):
            all_props = pd.DataFrame([], index=[])
            indices = pd.Index(indices, name='label')
properties = pd.DataFrame(properties, index=indices, columns=columns)

# %%
properties.head(24)

# %%
#Add I_Hoechst
I_Hoechst=[]
for z, frame in enumerate(labeled_stack):
    h_prop = regionprops(frame.astype(np.int),
                         intensity_image=im[z,:,:,0]) #0=Hoechst
    for d in h_prop:
        radius = (d.area / np.pi)**0.5
        if (min_radius  < radius < max_radius):
            I_Hoechst.append(d.mean_intensity * d.area)
            indices.append(d.label)
properties['I_Hoechst']=I_Hoechst

# %%
properties

# %%
#Calculate total GFP
Nuclear_GFP=properties['I_GFP'].sum()
print(Nuclear_GFP)

#Calculate total GFP
Nuclear_Hoechst=properties['I_Hoechst'].sum()
print(Nuclear_Hoechst)

# %%
#Compare intensity across z-stacks
properties.plot.scatter('I_Hoechst','I_GFP')

# %%
##Lets look at the GFP channel
GFP_stack=im[:,:,:,1]

nrows = np.int(np.ceil(np.sqrt(z_size)))
ncols = np.int(z_size // nrows + 1)

fig, axes = plt.subplots(nrows, ncols, figsize=(3*ncols, 3*nrows))
for n in range(z_size):
    i = n // ncols
    j = n % ncols
    axes[i, j].imshow(GFP_stack[n],
                      interpolation='nearest',
                      vmin=500,                     #constant minimum display value
                      vmax=6000                     #constant maximum display value
                      #cmap='gray'
                     )
    
    
## Remove empty plots 
for ax in axes.ravel():
    if not(len(ax.images)):
        fig.delaxes(ax)
fig.tight_layout()

# %%
#from skimage.feature import blob_log
#Detect maxima using 'blob_log' for more accurate detection. (Error messages suggest it only works on 2D arrays!!)
#Can't seem to get it to work at all
#blobs = blob_log(GFP_stack[0], threshold=.01)
#punc_fig = plt.figure(figsize=(12, 12))
#colors = plt.cm.jet(blobs[:,2].astype(np.int32))
#plt.imshow(GFP_stack[0], cmap='gray')
#plt.scatter(blobs[:,0],blobs[:,1], c=colors, alpha=1)

# %%
#Measure maxima intensities and count (bear in mind that we need to cluster to prevent over estimates)
#Max filter makes local maxima more obvious.
image_max=ndimage.maximum_filter(GFP_stack,footprint=np.ones((3,3,3)))
plt.imshow(image_max[3])

# %%
#local_max = ndimage.maximum_filter(GFP_stack, size=2.5)==GFP_stack
local_max = ndimage.maximum_filter(GFP_stack,footprint=np.ones((3,10,10)))==GFP_stack
plt.imshow(local_max[8], cmap="gray") #individual voxels are too small to see
##these are your markers

# %%
##Create mask
pT=4000
puncta=image_max>pT
plt.imshow(puncta[8])

# %%
##Identify local maxima within the nucleus
nu_pun=np.array(puncta) & np.array(ws_stack)
plt.imshow(nu_pun[3])
#plt.title('Puncta within the Nucleus')

##Get coordinates of local maxima
nu_max=np.array(local_max) & np.array(ws_stack)
plt.imshow(nu_max[3], cmap='gray')
#plt.title('Puncta within the Nucleus') #Voxels are hard to see on plot

# %%
##Coordinates of local maxima within the nucleus. Later replaced by coodrinates of local nuclear maxima > 4000.
header=(['z','r','c'])
coords=np.transpose(nu_max.nonzero())
coords = pd.DataFrame(coords, columns=header)
coords

# %%
#plt.scatter(512-coords['r'],
#           coords['c'], c=colors, alpha=1, vmin=0, vmax=512
#         )

scat_fig = plt.figure(figsize=(12, 12))
colors = plt.cm.jet(coords.index.astype(np.int32))

# xy projection:
scat_fig.imshow(nu_pun[3], cmap='gray')
scat_fig.scatter(coords['r'],
              coords['c'], c=colors, alpha=1)
plt.draw()

# %%
spot_distance = ndimage.distance_transform_edt(nu_pun)
plt.imshow(spot_distance[8])

# %%
fig = plt.figure(figsize=(12, 12))
colors = plt.cm.jet(properties.index.astype(np.int32))

# xy projection:
ax_xy = fig.add_subplot(111)
ax_xy.imshow(spot_distance.mean(axis=0), cmap='gray', vmin=0, vmax=2)
ax_xy.scatter(coords['c'],
              coords['r'], c=colors, alpha=1)

divider = make_axes_locatable(ax_xy)
ax_zx = divider.append_axes("top", 2, pad=0.2, sharex=ax_xy)
ax_zx.imshow(spot_distance.mean(axis=1), aspect=z_scale/xy_scale, cmap='gray')
ax_zx.scatter(coords['c'],
              coords['z'], c=colors, alpha=1)

ax_yz = divider.append_axes("right", 2, pad=0.2, sharey=ax_xy)
ax_yz.imshow(spot_distance.mean(axis=2).T, aspect=xy_scale/z_scale, cmap='gray')
ax_yz.scatter(coords['z'],
              coords['r'], c=colors, alpha=1)
plt.draw()

# %%
##Try overlaying local_max >4000
coords=[]

#[1] Mask GFP_stack with[nu_max]
GFP_ma=MA.masked_array(GFP_stack,
                      mask=~nu_max)

#plt.imshow(GFP_ma[12],
#           cmap='gray')

coords=np.transpose((GFP_stack>4000).nonzero())
coords = pd.DataFrame(coords, columns=header)
coords

# %%
markers=nu_max
punc_labels = watershed(-spot_distance,nu_pun, markers)
plt.imshow(punc_labels[3])

# %%
from skimage import segmentation
markers=nu_max
##
punc_labels = segmentation.random_walker(image_max, markers)
plt.imshow(punc_labels[3])

# %%
# xy projection:
plt.imshow(GFP_stack[1], cmap='gray')
plt.scatter(coordinates[1,:,0],
              coordinates[1,:,1], c=colors, alpha=1)

# %%
##Why not just threshold
pT=threshold_otsu(GFP_stack)

# %%
#pT=5*image_max.mean()
#pT=2500
puncta=image_max>pT
plt.imshow(puncta[12])

# %%
pT=threshold_otsu(GFP_ma)

# %%
GFP_ma=MA.masked_array(GFP_stack,
                      mask=~ws_stack)

plt.imshow(GFP_ma[12],
           cmap='gray')

# %%
GFP_ma.mean()

# %%
#Consider puncta within the nucleus. NB some puncta were cropped.
nu_pun=np.array(puncta) & np.array(ws_stack)
plt.imshow(nu_pun[11])
plt.title('Puncta within the Nucleus')

# %% [markdown]
# **Watershed Puncta**

# %%
spot_distance = ndimage.distance_transform_edt(nu_pun)
#plt.imshow(spot_distance[11])

# %%
plt.imshow(im[11,:,:,1],interpolation='nearest', cmap='gray')

# %%
    distance = ndimage.distance_transform_edt(frame)
    local_maxi = peak_local_max(
        distance, indices=False, footprint=np.ones((20, 20)), labels=frame)
    markers = ndimage.label(local_maxi)[0]
    labels = watershed(-distance, markers, mask=frame)

    ws_stack[z] = labels

# %% [markdown]
# **Label  and Cluster puncta**

# %%
#Labelling works with 3D arrays, so connectivity is already estabilshed
labeled_spots, nr_objects = mh.label(nu_pun)
labeled_spots
plt.imshow(labeled_spots[5])

# %%
labeled_spots.shape

# %% [markdown]
# **Measure puncta**

# %%
spot_properties=[]
columns = ('z','x','y','a','w','I')
spot_indices = []

g_prop=regionprops(labeled_spots.astype(np.int),
            intensity_image=im[:,:,:,1])
for d in g_prop:
    spot_properties.append([d.coords[:,0].mean(), #average the z-coordinates for voxels in this spot (frame)
                            d.coords[:,1].mean(), #average the x-coordinates for voxels in this spot (column)
                            d.coords[:,2].mean(), #average the y-coordinates for voxels in this spot (row)
                            d.area,
                            (d.area / np.pi)**0.5,
                            d.mean_intensity * d.area]) #area is just number of connected voxels)
    spot_indices.append(d.label)
spot_properties = pd.DataFrame(spot_properties, index=spot_indices, columns=columns)

# %%
spot_properties

# %%
#Compare intensity across z-stacks
#spot_properties.plot.scatter('w','I')
spot_properties.plot.scatter('x','z')
#spot_properties['I'].plot.hist(bins=20)

# %%
spot_fig = plt.figure(figsize=(12, 12))
colors = plt.cm.jet(properties.index.astype(np.int32))

# xy projection:
ax_xy = spot_fig.add_subplot(111)
ax_xy.imshow(image_max.max(axis=0), cmap='gray')
ax_xy.scatter(spot_properties['y'],
              spot_properties['x'], c=colors, alpha=1)

divider = make_axes_locatable(ax_xy)
ax_zx = divider.append_axes("top", 2, pad=0.2, sharex=ax_xy)
ax_zx.imshow(image_max.max(axis=1), aspect=z_scale/xy_scale, cmap='gray')
ax_zx.scatter(spot_properties['y'],
              spot_properties['z'], c=colors, alpha=1)
ax_yz = divider.append_axes("right", 2, pad=0.2, sharey=ax_xy)
ax_yz.imshow(image_max.max(axis=2).T, aspect=xy_scale/z_scale, cmap='gray')
ax_yz.scatter(spot_properties['z'],
              spot_properties['x'], c=colors, alpha=1)
plt.draw()

# %%
##Simplify this shit
spot_properties = []
columns = ('x', 'y', 'z', 'I', 'w')
spot_indices = []
min_spot_r=0
max_spot_r=50

for z, frame in enumerate(labeled_spots):
    g_prop = regionprops(frame.astype(np.int),
                         intensity_image=im[z,:,:,1]) #GFP
    for d in g_prop:
        radius = (d.area / np.pi)**0.5
        if (min_spot_r  < radius < max_spot_r):
            spot_properties.append([d.weighted_centroid[0],
                               d.weighted_centroid[1],
                               z, 
                               d.mean_intensity * d.area,
                               radius])
            spot_indices.append(d.label)
        if not len(indices):
            all_props = pd.DataFrame([], index=[])
            spot_indices = pd.Index(indices, name='label')
spot_properties = pd.DataFrame(spot_properties, index=indices, columns=columns)
#properties['I'] /= properties['I'].max() #This will normalise the intensities to the brightest.

# %%
##Should really just call the same labelling function used for nuclei labelling again here
spot_properties = []
columns = ('x', 'y', 'z', 'I', 'w')
spot_indices = []
min_spot_r=0
max_spot_r=50

for z, frame in enumerate(labeled_spots):
    g_prop = regionprops(frame.astype(np.int),
                         intensity_image=im[z,:,:,1]) #GFP
    for d in g_prop:
        radius = (d.area / np.pi)**0.5
        if (min_spot_r  < radius < max_spot_r):
            spot_properties.append([d.weighted_centroid[0],
                               d.weighted_centroid[1],
                               z, 
                               d.mean_intensity * d.area,
                               radius])
            spot_indices.append(d.label)
        if not len(indices):
            all_props = pd.DataFrame([], index=[])
            spot_indices = pd.Index(indices, name='label')
spot_properties = pd.DataFrame(spot_properties, index=indices, columns=columns)
#properties['I'] /= properties['I'].max() #This will normalise the intensities to the brightest.

# %% [markdown]
# **Cluster puncta**

# %%
size=5
peak_threshold=5000

#Find puncta
image_max = ndimage.maximum_filter(im[3,:,:,1], size=size, mode='constant')
puncta = (im[3,:,:,1] == image_max) #What is happening here
im[:,:,:,1] *= puncta

# Find peaks
image_t = (im[3,:,:,1] > peak_threshold) * 1

# get coordinates of peaks
f = np.transpose(image_t.nonzero())

# Show
img = plt.imshow(np.asarray(im[3,:,:,1]), cmap='gray')
plt.plot(f[:, 1], f[:, 0], 'o', markeredgewidth=0.45, markeredgecolor='b', markerfacecolor='None')

plt.axis('off')
plt.savefig('local_max.png', format='png', bbox_inches='tight')
plt.show()
